# %% [markdown]
# # Vergleich von Imputation Methoden

# %% [markdown]
# An dieser Stelle sollen verschiede Methoden zum interpolieren von fehlenden Werten betrachtet und verglichen werden.

# %% [markdown]
# ### Vorbereitung

# %%
import pandas as pd
import numpy as np
import math
import time

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer, KNNImputer

# %% [markdown]
# In der Folge werden keine Regionen oder Gruppierungen von Ländern und nur die Jahre ab 1990 betrachtet.
# Von dem verbliebenen Datensatz werden nur Indikatoren behalten, die mindesten 20% gefüllt sind und nach ihrer Relevanz manuell ausgewählt wurden (siehe 03_preparing_data).

# %%
def reset_base():
    base= pd.read_csv('additional_data/base.csv') 
    base.set_index(['Country Name', 'Indicator Name'], inplace=True)
    base = base.sort_index(level=['Country Name', 'Indicator Name'])
    return base

# %%
base = reset_base()
base.isna().sum().sum()
# Out:
# 170307

# %% [markdown]
# Um die Performanz unterschiedlicher Imutation Verfahren zu vergleichen werden weitere 1000 vorhandene (nicht NaN) Einträge entfernt. Diese 1000 Einträge werden später als Test-Daten verwendet, auf ihrer Grundlage lassen sich die Fehler der analysierten Verfahren errechnen. Um sicherzustellen, dass die Ergebnisse reproduzierbar sind wird ein Random State gesetzt. Dann werden zufällig Koordinaten zu Dateneinträgen gezogen. Da an dieser Stelle nur vorhandene Einträge relevant sind, werden zunächst zu viele Koordinaten gezogen, diese dann mit dem Datensatz abgeglichen und gelöscht, falls sie zu einem NaN zeigen und dann die ersten 1000 verbliebenen (und damit relevanten) Einträge ausgewählt. Diese werden in den Trainingsdaten entfernt. Auf diese Weise bleibt eine Reproduzierbarkeit erhalten.

# %%
base.head(3)
# Out:
#                                                                  1990  1991  \
# Country Name Indicator Name
# Afghanistan  Access to clean fuels and technologies for cook...   NaN   NaN
#              Access to electricity (% of population)              NaN   NaN
#              Access to electricity, rural (% of rural popula...   NaN   NaN
#
#                                                                  1992  1993  \
# Country Name Indicator Name
# Afghanistan  Access to clean fuels and technologies for cook...   NaN   NaN
#              Access to electricity (% of population)              NaN   NaN
#              Access to electricity, rural (% of rural popula...   NaN   NaN
#
#                                                                  1994  1995  \
# Country Name Indicator Name
# Afghanistan  Access to clean fuels and technologies for cook...   NaN   NaN
#              Access to electricity (% of population)              NaN   NaN
#              Access to electricity, rural (% of rural popula...   NaN   NaN
#
#                                                                  1996  1997  \
# Country Name Indicator Name
# Afghanistan  Access to clean fuels and technologies for cook...   NaN   NaN
#              Access to electricity (% of population)              NaN   NaN
#              Access to electricity, rural (% of rural popula...   NaN   NaN
#
#                                                                  1998  1999  \
# Country Name Indicator Name
# Afghanistan  Access to clean fuels and technologies for cook...   NaN   NaN
#              Access to electricity (% of population)              NaN   NaN
#              Access to electricity, rural (% of rural popula...   NaN   NaN
#
#                                                                  ...  \
# Country Name Indicator Name                                      ...
# Afghanistan  Access to clean fuels and technologies for cook...  ...
#              Access to electricity (% of population)             ...
#              Access to electricity, rural (% of rural popula...  ...
#
#                                                                       2011  \
# Country Name Indicator Name
# Afghanistan  Access to clean fuels and technologies for cook...  21.500000
#              Access to electricity (% of population)             43.222019
#              Access to electricity, rural (% of rural popula...  29.572881
#
#                                                                       2012  \
# Country Name Indicator Name
# Afghanistan  Access to clean fuels and technologies for cook...  23.000000
#              Access to electricity (% of population)             69.100000
#              Access to electricity, rural (% of rural popula...  60.849157
#
#                                                                       2013  \
# Country Name Indicator Name
# Afghanistan  Access to clean fuels and technologies for cook...  24.799999
#              Access to electricity (% of population)             68.982941
#              Access to electricity, rural (% of rural popula...  61.315788
#
#                                                                       2014  \
# Country Name Indicator Name
# Afghanistan  Access to clean fuels and technologies for cook...  26.700001
#              Access to electricity (% of population)             89.500000
#              Access to electricity, rural (% of rural popula...  86.500512
#
#                                                                       2015  \
# Country Name Indicator Name
# Afghanistan  Access to clean fuels and technologies for cook...  28.600000
#              Access to electricity (% of population)             71.500000
#              Access to electricity, rural (% of rural popula...  64.573354
#
#                                                                       2016  \
# Country Name Indicator Name
# Afghanistan  Access to clean fuels and technologies for cook...  30.299999
#              Access to electricity (% of population)             97.700000
#              Access to electricity, rural (% of rural popula...  97.099360
#
#                                                                       2017  \
# Country Name Indicator Name
# Afghanistan  Access to clean fuels and technologies for cook...  32.200001
#              Access to electricity (% of population)             97.700000
#              Access to electricity, rural (% of rural popula...  97.091973
#
#                                                                       2018  \
# Country Name Indicator Name
# Afghanistan  Access to clean fuels and technologies for cook...  34.099998
#              Access to electricity (% of population)             98.715622
#              Access to electricity, rural (% of rural popula...  98.309603
#
#                                                                      2019  \
# Country Name Indicator Name
# Afghanistan  Access to clean fuels and technologies for cook...  36.00000
#              Access to electricity (% of population)             97.70000
#              Access to electricity, rural (% of rural popula...  96.90219
#
#                                                                  2020
# Country Name Indicator Name
# Afghanistan  Access to clean fuels and technologies for cook...   NaN
#              Access to electricity (% of population)              NaN
#              Access to electricity, rural (% of rural popula...   NaN
#
# [3 rows x 31 columns]

# %% [markdown]
# ### Simulation fehlender Werte und Evaluation

# %%
def get_cords(frac):
    n = int(base.isna().sum().sum()*frac)
    print(f'Testdaten mit {frac*100}% fehlenden Werten (absolut: {n})')
    #random state to ensure reproducibility
    rnds = np.random.RandomState(n)

    #coordinates for data entries to be removed randomly
    #5000 entries are selected
    cords = pd.DataFrame([[rnds.randint(0, len(base), size=n*4)[i], 
                  rnds.randint(0, len(base.columns), size=n*4)[i]]
                  for i in range(n*4)])

    #all coordinates pointing to NaN entries are removed and
    #first 1000 remaining entries are selected
    cords['value'] = [base.iloc[cords[0][i], cords[1][i]] for i in cords.index]
    cords = cords.dropna()[:n].reset_index(drop=True)
    
    return cords

# %%
cords = get_cords(0.05)
# Out:
# Testdaten mit 5.0% fehlenden Werten (absolut: 8515)

# %%
#getting train data by changing randomly chosen values to NaN
def reset_train(cords):
    train = base.copy()
    for i in cords.index:
        train.iloc[cords[0][i], cords[1][i]] = None
    return train

# %%
results = []

# %%
def evaluate(method, df, t, results):
    
        
    #scaling original data and imputed data
    #necessary ?????????????????????????????????????
    train = reset_train(cords)
    scaler = StandardScaler().fit(train) #fitting on train?
    norm_base = pd.DataFrame(scaler.transform(base))
    df = pd.DataFrame(scaler.transform(df))

    #getting imputed values for simulated NaNs and true value 
    res =pd.DataFrame({'y_true': [norm_base.iloc[cords[0][i], cords[1][i]] for i in cords.index],
                       'y_pred': [df.iloc[cords[0][i], cords[1][i]] for i in cords.index]
                      })
    res = res.dropna()

   
    #calculate evaluation metrics
    r2 = r2_score(res['y_true'], res['y_pred'])
    rmse = math.sqrt(mean_squared_error(res['y_true'], res['y_pred']))
    still_missing = df.isna().sum().sum()
    
    print(f'Mit dieser Methode bleiben {still_missing} NaNs bestehen.')
    print('')
    print(f'{len(res)} Werte wurden für die Metriken verwendet.')
    print(f'r2: {r2}, rmse: {rmse}')
    
    results.append([method, r2, rmse, still_missing, t])
    return results

# %% [markdown]
# ###  Imputation Verfahren

# %% [markdown]
# Es werden diese Imputation Methoden verglichen:
# - Backcasting
# - Durchschnitt
# - regionaler Durchschnitt
# - Iterative Imputer
# - KNN Imputer

# %% [markdown]
# #### Backfill

# %%
def impute_backfill(df):
    df = df.fillna(method='bfill', limit=3)
    return df

# %%
base = reset_base()
train = reset_train(cords)



t0 = time.time()
df= impute_backfill(train) 
t1 = time.time()

t = t1-t0

df.to_csv('additional_data/imputed_sets/backfill.csv')
results = evaluate('Backfill', df, t, results)
# Out:
# Mit dieser Methode bleiben 32853 NaNs bestehen.
#
# 8256 Werte wurden für die Metriken verwendet.
# r2: -16.124570911516813, rmse: 1.683781763968918

# %% [markdown]
# #### Durchschnitt des Indikators über alle Jahre hinweg

# %%
def impute_overall_means(df):
    #fill NaNs with overall mean of that indicator
    values = pd.DataFrame(df.stack()).groupby('Indicator Name')[0].mean()
    df = pd.DataFrame(df.stack(dropna=False))
    
    df[0] = df[0].fillna(df.groupby('Indicator Name')[0].transform('mean'))
    df = df.unstack()
    df.columns = df.columns.droplevel(0)
    df = df.sort_index(level=['Country Name', 'Indicator Name'])
        
    return df

# %%
base = reset_base()
train = reset_train(cords)

t0 = time.time()
df = impute_overall_means(train)
t1 = time.time()

t = t1-t0

df.to_csv('additional_data/imputed_sets/mean.csv')
evaluate('Overall Mean', df, t, results)
# Out:
# Mit dieser Methode bleiben 0 NaNs bestehen.
#
# 8515 Werte wurden für die Metriken verwendet.
# r2: -2.231564589450377, rmse: 0.7202445836681456
# [['Backfill',
#   -16.124570911516813,
#   1.683781763968918,
#   32853,
#   0.0156252384185791],
#  ['Overall Mean',
#   -2.231564589450377,
#   0.7202445836681456,
#   0,
#   0.33020544052124023]]

# %% [markdown]
# #### Durchschnitt des Indikators für das jeweilige Jahr

# %%
def impute_yearly_means(df):
    #fill NaNs with overall mean of that indicator
    
    for i in df.columns:
        df[i] = df[i].fillna(df.groupby('Indicator Name')[i].transform('mean'))
            
    return df

# %%
base = reset_base()
train = reset_train(cords)

t0 = time.time()
df = impute_yearly_means(train)
t1 = time.time()

t = t1-t0

evaluate('Yearly Mean',df, t, results)
# Out:
# Mit dieser Methode bleiben 52298 NaNs bestehen.
#
# 8515 Werte wurden für die Metriken verwendet.
# r2: -0.09704256669343403, rmse: 0.41964815712332865
# [['Backfill',
#   -16.124570911516813,
#   1.683781763968918,
#   32853,
#   0.0156252384185791],
#  ['Overall Mean',
#   -2.231564589450377,
#   0.7202445836681456,
#   0,
#   0.33020544052124023],
#  ['Yearly Mean',
#   -0.09704256669343403,
#   0.41964815712332865,
#   52298,
#   0.10567331314086914]]

# %% [markdown]
# #### Regionaler Durchschnitt des Indikators für das jeweilige Jahr

# %%
def impute_yearly_means_per_region(df):
    country_data = pd.read_csv('../Data/WDICountry.csv')
    country_data = country_data.loc[:,['Table Name', 'Region']]
    df = pd.merge(df.reset_index(), country_data, how='left', left_on='Country Name', right_on='Table Name').drop('Table Name', axis=1)
    df = df.set_index(['Country Name', 'Indicator Name', 'Region'])

    for i in df.columns:
        df[i] = df[i].fillna(df.groupby(['Indicator Name', 'Region'])[i].transform('mean'))

    df = df.reset_index().set_index(['Country Name', 'Indicator Name']).drop('Region', axis=1)
    return df

# %%
base = reset_base()
train = reset_train(cords)

t0 = time.time()
df = impute_yearly_means_per_region(train)
t1 = time.time()

t = t1-t0

evaluate('Yearly Mean per Region', df, t, results)
# Out:
# Mit dieser Methode bleiben 57262 NaNs bestehen.
#
# 8458 Werte wurden für die Metriken verwendet.
# r2: -0.4349777575022391, rmse: 0.4815635503840548
# [['Backfill',
#   -16.124570911516813,
#   1.683781763968918,
#   32853,
#   0.0156252384185791],
#  ['Overall Mean',
#   -2.231564589450377,
#   0.7202445836681456,
#   0,
#   0.33020544052124023],
#  ['Yearly Mean',
#   -0.09704256669343403,
#   0.41964815712332865,
#   52298,
#   0.10567331314086914],
#  ['Yearly Mean per Region',
#   -0.4349777575022391,
#   0.4815635503840548,
#   57262,
#   0.25169897079467773]]

# %% [markdown]
# #### Interpolation

# %%
def interpolate3(df):
    df = df.interpolate(limit=3)
    return df

def interpolate_all(df):
    df = df.interpolate()
    return df

# %%
base = reset_base()
train = reset_train(cords)

t0 = time.time()
df = interpolate3(train)
t1 = time.time()

t = t1-t0

evaluate('Interpolation 3', df, t, results)
# Out:
# Mit dieser Methode bleiben 32884 NaNs bestehen.
#
# 8235 Werte wurden für die Metriken verwendet.
# r2: -2.959611964171229, rmse: 0.810691330925762
# [['Backfill',
#   -16.124570911516813,
#   1.683781763968918,
#   32853,
#   0.0156252384185791],
#  ['Overall Mean',
#   -2.231564589450377,
#   0.7202445836681456,
#   0,
#   0.33020544052124023],
#  ['Yearly Mean',
#   -0.09704256669343403,
#   0.41964815712332865,
#   52298,
#   0.10567331314086914],
#  ['Yearly Mean per Region',
#   -0.4349777575022391,
#   0.4815635503840548,
#   57262,
#   0.25169897079467773],
#  ['Interpolation 3',
#   -2.959611964171229,
#   0.810691330925762,
#   32884,
#   0.11022782325744629]]

# %%
base = reset_base()
train = reset_train(cords)

t0 = time.time()
df = interpolate_all(train)
t1 = time.time()

t = t1-t0

df.to_csv('additional_data/imputed_sets/interpolation.csv')
results = evaluate('Interpolation all', df, t, results)
# Out:
# Mit dieser Methode bleiben 58 NaNs bestehen.
#
# 8515 Werte wurden für die Metriken verwendet.
# r2: -2.959674983506685, rmse: 0.7972661962988941

# %% [markdown]
# #### Iterative Imputer

# %% [markdown]
# An dieser Stelle wird der Iterative Imputer von SciKitLearn angewandt. Die drei Varianten laufen auf den drei Dimensionen des Datensatzes.

# %%
def iterative_imputer_1(df):
    col = df.columns
    idx = df.index
    
    iter_imp = IterativeImputer(random_state=999)
    df= iter_imp.fit_transform(df)
    df= pd.DataFrame(df, columns=col, index=idx)
    return df

def iterative_imputer_2(df):
    df = df.unstack().T
    col = df.columns
    idx = df.index

    iter_imp = IterativeImputer(random_state=999)
    df= iter_imp.fit_transform(df)

    df = pd.DataFrame(df, columns=col, index=idx)
    df = df.unstack().T
    df = df.sort_index(level=['Country Name', 'Indicator Name'])
    
    return df

def iterative_imputer_3(df):

    df = df.reset_index()
    df = df.set_index(['Indicator Name', 'Country Name'])
    df = df.unstack().T

    col = df.columns
    idx = df.index

    iter_imp = IterativeImputer(random_state=999, verbose=True)
    df= iter_imp.fit_transform(df)

    df = pd.DataFrame(df, columns=col, index=idx)
    df = df.unstack().T
    df = df.reset_index()
    df = df.set_index(['Country Name', 'Indicator Name'])
    df = df.sort_index(level=['Country Name', 'Indicator Name'])
    
    return df

# %%
base = reset_base()
train = reset_train(cords)

t0 = time.time()
df = iterative_imputer_1(train)
t1 = time.time()

t = t1-t0

df.to_csv('additional_data/imputed_sets/ice.csv')
results = evaluate('Iterative Imputer 1', df, t, results)
# Out:
# C:\Users\mbfbr\Anaconda3\envs\other\lib\site-packages\sklearn\impute\_iterative.py:699: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Mit dieser Methode bleiben 0 NaNs bestehen.
#
# 8515 Werte wurden für die Metriken verwendet.
# r2: 0.9609051476884861, rmse: 0.07921973204963073

# %%
base = reset_base()
train = reset_train(cords)

t0 = time.time()
df = iterative_imputer_2(train)
t1 = time.time()

t = t1-t0

df.to_csv('additional_data/imputed_sets/ice2.csv')
results = evaluate('Iterative Imputer 2', df, t, results)
# Out:
# Mit dieser Methode bleiben 0 NaNs bestehen.
#
# 8515 Werte wurden für die Metriken verwendet.
# r2: 0.9661514177508125, rmse: 0.07371295511229263

# %%
base = reset_base()
train = reset_train(cords)

t0 = time.time()
df = iterative_imputer_3(train)
t1 = time.time()

t = t1-t0

df.to_csv('additional_data/imputed_sets/ice3.csv')
results = evaluate('Iterative Imputer 3', df, t, results)
# Out:
# [IterativeImputer] Completing matrix with shape (4898, 165)
# [IterativeImputer] Change: 3.147511124721088e+16, scaled tolerance: 35084726045503.402
# [IterativeImputer] Change: 1034671076716780.0, scaled tolerance: 35084726045503.402
# [IterativeImputer] Change: 659123757395787.5, scaled tolerance: 35084726045503.402
# [IterativeImputer] Change: 616363768648911.4, scaled tolerance: 35084726045503.402
# [IterativeImputer] Change: 2396881809792168.5, scaled tolerance: 35084726045503.402
# [IterativeImputer] Change: 603334623851478.6, scaled tolerance: 35084726045503.402
# [IterativeImputer] Change: 3452555317561406.0, scaled tolerance: 35084726045503.402
# [IterativeImputer] Change: 1566687283686987.5, scaled tolerance: 35084726045503.402
# [IterativeImputer] Change: 562306276969730.8, scaled tolerance: 35084726045503.402
# [IterativeImputer] Change: 263990229283100.84, scaled tolerance: 35084726045503.402
# C:\Users\mbfbr\Anaconda3\envs\other\lib\site-packages\sklearn\impute\_iterative.py:699: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Mit dieser Methode bleiben 0 NaNs bestehen.
#
# 8515 Werte wurden für die Metriken verwendet.
# r2: 0.662632017747099, rmse: 0.2327156083233093

# %% [markdown]
# #### MICE

# %%
def mice_imputer(df):
    n_imputations =  12
    dfs = []
    col = df.columns
    idx = df.index
    
    for i in range(n_imputations): 
        print(f'Imputation round {i}')
        iter_imp = IterativeImputer(random_state=i, sample_posterior=True, verbose=2)
        df_temp = iter_imp.fit_transform(df)
        dfs.append(df_temp)
    
    df = np.mean(np.array(dfs), axis=0)
    df = pd.DataFrame(df, columns=col, index=idx)
    return df

# %%
base = reset_base()
train = reset_train(cords)

t0 = time.time()
df = mice_imputer(train)
t1 = time.time()

t = t1-t0
df.to_csv('additional_data/imputed_sets/mice.csv')
# Out:
# Imputation round 0
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 14.92
# [IterativeImputer] Ending imputation round 2/10, elapsed time 29.54
# [IterativeImputer] Ending imputation round 3/10, elapsed time 44.05
# [IterativeImputer] Ending imputation round 4/10, elapsed time 58.46
# [IterativeImputer] Ending imputation round 5/10, elapsed time 73.05
# [IterativeImputer] Ending imputation round 6/10, elapsed time 87.60
# [IterativeImputer] Ending imputation round 7/10, elapsed time 102.15
# [IterativeImputer] Ending imputation round 8/10, elapsed time 116.92
# [IterativeImputer] Ending imputation round 9/10, elapsed time 131.50
# [IterativeImputer] Ending imputation round 10/10, elapsed time 146.14
# Imputation round 1
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 14.69
# [IterativeImputer] Ending imputation round 2/10, elapsed time 29.42
# [IterativeImputer] Ending imputation round 3/10, elapsed time 44.06
# [IterativeImputer] Ending imputation round 4/10, elapsed time 58.78
# [IterativeImputer] Ending imputation round 5/10, elapsed time 73.08
# [IterativeImputer] Ending imputation round 6/10, elapsed time 87.56
# [IterativeImputer] Ending imputation round 7/10, elapsed time 102.07
# [IterativeImputer] Ending imputation round 8/10, elapsed time 116.52
# [IterativeImputer] Ending imputation round 9/10, elapsed time 131.13
# [IterativeImputer] Ending imputation round 10/10, elapsed time 145.66
# Imputation round 2
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 14.78
# [IterativeImputer] Ending imputation round 2/10, elapsed time 29.40
# [IterativeImputer] Ending imputation round 3/10, elapsed time 44.11
# [IterativeImputer] Ending imputation round 4/10, elapsed time 58.42
# [IterativeImputer] Ending imputation round 5/10, elapsed time 72.89
# [IterativeImputer] Ending imputation round 6/10, elapsed time 87.45
# [IterativeImputer] Ending imputation round 7/10, elapsed time 102.05
# [IterativeImputer] Ending imputation round 8/10, elapsed time 116.88
# [IterativeImputer] Ending imputation round 9/10, elapsed time 131.26
# [IterativeImputer] Ending imputation round 10/10, elapsed time 145.82
# Imputation round 3
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 14.89
# [IterativeImputer] Ending imputation round 2/10, elapsed time 29.54
# [IterativeImputer] Ending imputation round 3/10, elapsed time 44.03
# [IterativeImputer] Ending imputation round 4/10, elapsed time 58.40
# [IterativeImputer] Ending imputation round 5/10, elapsed time 73.01
# [IterativeImputer] Ending imputation round 6/10, elapsed time 87.51
# [IterativeImputer] Ending imputation round 7/10, elapsed time 101.82
# [IterativeImputer] Ending imputation round 8/10, elapsed time 116.26
# [IterativeImputer] Ending imputation round 9/10, elapsed time 130.99
# [IterativeImputer] Ending imputation round 10/10, elapsed time 145.39
# Imputation round 4
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 14.56
# [IterativeImputer] Ending imputation round 2/10, elapsed time 29.13
# [IterativeImputer] Ending imputation round 3/10, elapsed time 43.82
# [IterativeImputer] Ending imputation round 4/10, elapsed time 58.36
# [IterativeImputer] Ending imputation round 5/10, elapsed time 72.77
# [IterativeImputer] Ending imputation round 6/10, elapsed time 87.30
# [IterativeImputer] Ending imputation round 7/10, elapsed time 101.63
# [IterativeImputer] Ending imputation round 8/10, elapsed time 116.06
# [IterativeImputer] Ending imputation round 9/10, elapsed time 130.50
# [IterativeImputer] Ending imputation round 10/10, elapsed time 144.94
# Imputation round 5
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 14.42
# [IterativeImputer] Ending imputation round 2/10, elapsed time 29.19
# [IterativeImputer] Ending imputation round 3/10, elapsed time 43.51
# [IterativeImputer] Ending imputation round 4/10, elapsed time 57.82
# [IterativeImputer] Ending imputation round 5/10, elapsed time 72.29
# [IterativeImputer] Ending imputation round 6/10, elapsed time 86.98
# [IterativeImputer] Ending imputation round 7/10, elapsed time 101.49
# [IterativeImputer] Ending imputation round 8/10, elapsed time 116.08
# [IterativeImputer] Ending imputation round 9/10, elapsed time 130.66
# [IterativeImputer] Ending imputation round 10/10, elapsed time 145.20
# Imputation round 6
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 14.50
# [IterativeImputer] Ending imputation round 2/10, elapsed time 28.87
# [IterativeImputer] Ending imputation round 3/10, elapsed time 43.18
# [IterativeImputer] Ending imputation round 4/10, elapsed time 57.57
# [IterativeImputer] Ending imputation round 5/10, elapsed time 72.01
# [IterativeImputer] Ending imputation round 6/10, elapsed time 86.35
# [IterativeImputer] Ending imputation round 7/10, elapsed time 101.42
# [IterativeImputer] Ending imputation round 8/10, elapsed time 115.87
# [IterativeImputer] Ending imputation round 9/10, elapsed time 130.42
# [IterativeImputer] Ending imputation round 10/10, elapsed time 144.81
# Imputation round 7
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 14.48
# [IterativeImputer] Ending imputation round 2/10, elapsed time 29.17
# [IterativeImputer] Ending imputation round 3/10, elapsed time 43.67
# [IterativeImputer] Ending imputation round 4/10, elapsed time 58.20
# [IterativeImputer] Ending imputation round 5/10, elapsed time 72.92
# [IterativeImputer] Ending imputation round 6/10, elapsed time 87.32
# [IterativeImputer] Ending imputation round 7/10, elapsed time 101.73
# [IterativeImputer] Ending imputation round 8/10, elapsed time 116.15
# [IterativeImputer] Ending imputation round 9/10, elapsed time 130.82
# [IterativeImputer] Ending imputation round 10/10, elapsed time 145.35
# Imputation round 8
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 14.83
# [IterativeImputer] Ending imputation round 2/10, elapsed time 29.31
# [IterativeImputer] Ending imputation round 3/10, elapsed time 43.90
# [IterativeImputer] Ending imputation round 4/10, elapsed time 58.29
# [IterativeImputer] Ending imputation round 5/10, elapsed time 72.71
# [IterativeImputer] Ending imputation round 6/10, elapsed time 87.24
# [IterativeImputer] Ending imputation round 7/10, elapsed time 101.53
# [IterativeImputer] Ending imputation round 8/10, elapsed time 116.22
# [IterativeImputer] Ending imputation round 9/10, elapsed time 130.86
# [IterativeImputer] Ending imputation round 10/10, elapsed time 145.20
# Imputation round 9
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 14.34
# [IterativeImputer] Ending imputation round 2/10, elapsed time 28.73
# [IterativeImputer] Ending imputation round 3/10, elapsed time 43.19
# [IterativeImputer] Ending imputation round 4/10, elapsed time 57.71
# [IterativeImputer] Ending imputation round 5/10, elapsed time 72.32
# [IterativeImputer] Ending imputation round 6/10, elapsed time 86.77
# [IterativeImputer] Ending imputation round 7/10, elapsed time 101.17
# [IterativeImputer] Ending imputation round 8/10, elapsed time 115.99
# [IterativeImputer] Ending imputation round 9/10, elapsed time 130.38
# [IterativeImputer] Ending imputation round 10/10, elapsed time 144.67
# Imputation round 10
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 14.42
# [IterativeImputer] Ending imputation round 2/10, elapsed time 28.60
# [IterativeImputer] Ending imputation round 3/10, elapsed time 45.46
# [IterativeImputer] Ending imputation round 4/10, elapsed time 60.82
# [IterativeImputer] Ending imputation round 5/10, elapsed time 76.18
# [IterativeImputer] Ending imputation round 6/10, elapsed time 91.36
# [IterativeImputer] Ending imputation round 7/10, elapsed time 105.95
# [IterativeImputer] Ending imputation round 8/10, elapsed time 121.05
# [IterativeImputer] Ending imputation round 9/10, elapsed time 136.21
# [IterativeImputer] Ending imputation round 10/10, elapsed time 151.44
# Imputation round 11
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 15.54
# [IterativeImputer] Ending imputation round 2/10, elapsed time 30.40
# [IterativeImputer] Ending imputation round 3/10, elapsed time 44.93
# [IterativeImputer] Ending imputation round 4/10, elapsed time 59.85
# [IterativeImputer] Ending imputation round 5/10, elapsed time 73.99
# [IterativeImputer] Ending imputation round 6/10, elapsed time 88.39
# [IterativeImputer] Ending imputation round 7/10, elapsed time 102.64
# [IterativeImputer] Ending imputation round 8/10, elapsed time 117.09
# [IterativeImputer] Ending imputation round 9/10, elapsed time 131.28
# [IterativeImputer] Ending imputation round 10/10, elapsed time 145.49

# %%
results = evaluate('MICE', df, t, results)
# Out:
# Mit dieser Methode bleiben 0 NaNs bestehen.
#
# 8515 Werte wurden für die Metriken verwendet.
# r2: 0.9588865414805373, rmse: 0.08123919037202011

# %% [markdown]
# #### KNN Imputer

# %%
def knn_imputer1(df):
    col = df.columns
    idx = df.index
    
    knn_imp = KNNImputer(n_neighbors=2)
    df= knn_imp.fit_transform(df)
    df = pd.DataFrame(df, columns=col, index=idx)
    return df

def knn_imputer2(df, n):
    
    df = df.reset_index()
    df = df.set_index(['Indicator Name', 'Country Name'])
    df = df.unstack().T

    col = df.columns
    idx = df.index

    knn_imp = KNNImputer(n_neighbors=n)
    df= knn_imp.fit_transform(df)
    df = pd.DataFrame(df, columns=col, index=idx)

    df = df.unstack().T
    df = df.reset_index()
    df = df.set_index(['Country Name', 'Indicator Name'])
    df = df.sort_index(level=['Country Name', 'Indicator Name'])
    
    return df

# %%
base = reset_base()
train = reset_train(cords)

t0 = time.time()
df = knn_imputer1(train)
t1 = time.time()

t = t1-t0

results = evaluate('KNN Imputer1', df, t, results)
# Out:
# Mit dieser Methode bleiben 0 NaNs bestehen.
#
# 8515 Werte wurden für die Metriken verwendet.
# r2: 0.2944522579857045, rmse: 0.3365400724328245

# %%
base = reset_base()
train = reset_train(cords)

t0 = time.time()
df = knn_imputer2(train, 4)
t1 = time.time()

t = t1-t0

df.to_csv('additional_data/imputed_sets/knn.csv')
results= evaluate('KNN Imputer2', df, t, results)
# Out:
# Mit dieser Methode bleiben 0 NaNs bestehen.
#
# 8515 Werte wurden für die Metriken verwendet.
# r2: 0.9700605815538997, rmse: 0.06932585920533507

# %%
cords = get_cords(0.075)
results7 = []
# Out:
# Testdaten mit 7.5% fehlenden Werten (absolut: 12773)

# %%
base = reset_base()
train = reset_train(cords)

t0 = time.time()
df= impute_backfill(train) 
t1 = time.time()

t = t1-t0

results7 = evaluate('Backfill', df, t, results)

###mean
base = reset_base()
train = reset_train(cords)

t0 = time.time()
df = impute_overall_means(train)
t1 = time.time()

t = t1-t0
results7 = evaluate('Overall Mean', df, t, results)


base = reset_base()
train = reset_train(cords)

t0 = time.time()
df = impute_yearly_means(train)
t1 = time.time()

t = t1-t0

results7 = evaluate('Yearly Mean', df, t, results)


base = reset_base()
train = reset_train(cords)

t0 = time.time()
df = impute_yearly_means_per_region(train)
t1 = time.time()

t = t1-t0

results7 = evaluate('Yearly Mean per Region', df, t, results)

base = reset_base()
train = reset_train(cords)

t0 = time.time()
df = interpolate3(train)
t1 = time.time()

t = t1-t0

results7 = evaluate('Interpolation 3', df, t, results)

base = reset_base()
train = reset_train(cords)

t0 = time.time()
df = interpolate_all(train)
t1 = time.time()

t = t1-t0

results7 = evaluate('Interpolation all', df, t, results)

base = reset_base()
train = reset_train(cords)

t0 = time.time()
df = iterative_imputer_1(train)
t1 = time.time()

t = t1-t0

results7 = evaluate('Iterative Imputer 1', df, t, results)

base = reset_base()
train = reset_train(cords)

t0 = time.time()
df = iterative_imputer_2(train)
t1 = time.time()

t = t1-t0
results7 = evaluate('Iterative Imputer 2', df, t, results)

base = reset_base()
train = reset_train(cords)

t0 = time.time()
df = iterative_imputer_3(train)
t1 = time.time()

t = t1-t0
results7 = evaluate('Iterative Imputer 3', df, t, results)

base = reset_base()
train = reset_train(cords)

t0 = time.time()
df = mice_imputer(train)
t1 = time.time()

t = t1-t0
results7 = evaluate('MICE', df, t, results)

base = reset_base()
train = reset_train(cords)

t0 = time.time()
df = knn_imputer1(train)
t1 = time.time()

t = t1-t0

results7 = evaluate('KNN Imputer 1', df, t, results)

base = reset_base()
train = reset_train(cords)

t0 = time.time()
df = knn_imputer2(train, 4)
t1 = time.time()

t = t1-t0

results7 = evaluate('KNN Imputer 2', df, t, results)
# Out:
# Mit dieser Methode bleiben 33291 NaNs bestehen.
#
# 12357 Werte wurden für die Metriken verwendet.
# r2: -0.6130335478126085, rmse: 2.204393317611659
# Mit dieser Methode bleiben 0 NaNs bestehen.
#
# 12773 Werte wurden für die Metriken verwendet.
# r2: -0.07966531009333178, rmse: 1.7739835611317705
# Mit dieser Methode bleiben 52456 NaNs bestehen.
#
# 12772 Werte wurden für die Metriken verwendet.
# r2: 0.018306571582603737, rmse: 1.6916478144616887
# Mit dieser Methode bleiben 57327 NaNs bestehen.
#
# 12675 Werte wurden für die Metriken verwendet.
# r2: 0.04750946031970027, rmse: 1.6726391400547882
# Mit dieser Methode bleiben 33321 NaNs bestehen.
#
# 12344 Werte wurden für die Metriken verwendet.
# r2: -0.16049147170655953, rmse: 1.8708552797202576
# Mit dieser Methode bleiben 58 NaNs bestehen.
#
# 12773 Werte wurden für die Metriken verwendet.
# r2: -0.16047092507932859, rmse: 1.8391711645406432
# C:\Users\mbfbr\Anaconda3\envs\other\lib\site-packages\sklearn\impute\_iterative.py:699: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Mit dieser Methode bleiben 0 NaNs bestehen.
#
# 12773 Werte wurden für die Metriken verwendet.
# r2: 0.9887340145516139, rmse: 0.1812131084938613
# Mit dieser Methode bleiben 0 NaNs bestehen.
#
# 12773 Werte wurden für die Metriken verwendet.
# r2: 0.9869415093055817, rmse: 0.19509741234578154
# [IterativeImputer] Completing matrix with shape (4898, 165)
# [IterativeImputer] Change: 3.629456857808196e+16, scaled tolerance: 35084726045503.402
# [IterativeImputer] Change: 3247758564798911.0, scaled tolerance: 35084726045503.402
# [IterativeImputer] Change: 2759587364532460.5, scaled tolerance: 35084726045503.402
# [IterativeImputer] Change: 1656926274554512.0, scaled tolerance: 35084726045503.402
# [IterativeImputer] Change: 778581988678064.2, scaled tolerance: 35084726045503.402
# [IterativeImputer] Change: 339214715632727.56, scaled tolerance: 35084726045503.402
# [IterativeImputer] Change: 122409791482366.77, scaled tolerance: 35084726045503.402
# [IterativeImputer] Change: 176705508430741.7, scaled tolerance: 35084726045503.402
# [IterativeImputer] Change: 131066449435173.1, scaled tolerance: 35084726045503.402
# [IterativeImputer] Change: 144495167511924.62, scaled tolerance: 35084726045503.402
# C:\Users\mbfbr\Anaconda3\envs\other\lib\site-packages\sklearn\impute\_iterative.py:699: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Mit dieser Methode bleiben 0 NaNs bestehen.
#
# 12773 Werte wurden für die Metriken verwendet.
# r2: 0.9349444555054636, rmse: 0.43545890415417043
# Imputation round 0
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 14.56
# [IterativeImputer] Ending imputation round 2/10, elapsed time 29.22
# [IterativeImputer] Ending imputation round 3/10, elapsed time 43.93
# [IterativeImputer] Ending imputation round 4/10, elapsed time 58.48
# [IterativeImputer] Ending imputation round 5/10, elapsed time 73.09
# [IterativeImputer] Ending imputation round 6/10, elapsed time 87.77
# [IterativeImputer] Ending imputation round 7/10, elapsed time 102.25
# [IterativeImputer] Ending imputation round 8/10, elapsed time 116.80
# [IterativeImputer] Ending imputation round 9/10, elapsed time 131.29
# [IterativeImputer] Ending imputation round 10/10, elapsed time 145.93
# Imputation round 1
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 14.72
# [IterativeImputer] Ending imputation round 2/10, elapsed time 29.12
# [IterativeImputer] Ending imputation round 3/10, elapsed time 43.97
# [IterativeImputer] Ending imputation round 4/10, elapsed time 58.62
# [IterativeImputer] Ending imputation round 5/10, elapsed time 73.25
# [IterativeImputer] Ending imputation round 6/10, elapsed time 87.92
# [IterativeImputer] Ending imputation round 7/10, elapsed time 102.51
# [IterativeImputer] Ending imputation round 8/10, elapsed time 117.22
# [IterativeImputer] Ending imputation round 9/10, elapsed time 131.62
# [IterativeImputer] Ending imputation round 10/10, elapsed time 146.31
# Imputation round 2
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 14.72
# [IterativeImputer] Ending imputation round 2/10, elapsed time 29.48
# [IterativeImputer] Ending imputation round 3/10, elapsed time 44.28
# [IterativeImputer] Ending imputation round 4/10, elapsed time 58.87
# [IterativeImputer] Ending imputation round 5/10, elapsed time 73.38
# [IterativeImputer] Ending imputation round 6/10, elapsed time 87.96
# [IterativeImputer] Ending imputation round 7/10, elapsed time 102.50
# [IterativeImputer] Ending imputation round 8/10, elapsed time 117.20
# [IterativeImputer] Ending imputation round 9/10, elapsed time 131.92
# [IterativeImputer] Ending imputation round 10/10, elapsed time 146.64
# Imputation round 3
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 14.56
# [IterativeImputer] Ending imputation round 2/10, elapsed time 29.20
# [IterativeImputer] Ending imputation round 3/10, elapsed time 43.85
# [IterativeImputer] Ending imputation round 4/10, elapsed time 58.53
# [IterativeImputer] Ending imputation round 5/10, elapsed time 73.04
# [IterativeImputer] Ending imputation round 6/10, elapsed time 87.60
# [IterativeImputer] Ending imputation round 7/10, elapsed time 102.22
# [IterativeImputer] Ending imputation round 8/10, elapsed time 116.81
# [IterativeImputer] Ending imputation round 9/10, elapsed time 131.30
# [IterativeImputer] Ending imputation round 10/10, elapsed time 145.82
# Imputation round 4
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 14.55
# [IterativeImputer] Ending imputation round 2/10, elapsed time 29.06
# [IterativeImputer] Ending imputation round 3/10, elapsed time 43.53
# [IterativeImputer] Ending imputation round 4/10, elapsed time 58.01
# [IterativeImputer] Ending imputation round 5/10, elapsed time 72.71
# [IterativeImputer] Ending imputation round 6/10, elapsed time 87.52
# [IterativeImputer] Ending imputation round 7/10, elapsed time 102.01
# [IterativeImputer] Ending imputation round 8/10, elapsed time 116.63
# [IterativeImputer] Ending imputation round 9/10, elapsed time 131.10
# [IterativeImputer] Ending imputation round 10/10, elapsed time 145.71
# Imputation round 5
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 14.40
# [IterativeImputer] Ending imputation round 2/10, elapsed time 28.85
# [IterativeImputer] Ending imputation round 3/10, elapsed time 43.41
# [IterativeImputer] Ending imputation round 4/10, elapsed time 58.14
# [IterativeImputer] Ending imputation round 5/10, elapsed time 72.76
# [IterativeImputer] Ending imputation round 6/10, elapsed time 87.31
# [IterativeImputer] Ending imputation round 7/10, elapsed time 101.95
# [IterativeImputer] Ending imputation round 8/10, elapsed time 116.41
# [IterativeImputer] Ending imputation round 9/10, elapsed time 131.12
# [IterativeImputer] Ending imputation round 10/10, elapsed time 145.90
# Imputation round 6
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 14.73
# [IterativeImputer] Ending imputation round 2/10, elapsed time 29.48
# [IterativeImputer] Ending imputation round 3/10, elapsed time 44.02
# [IterativeImputer] Ending imputation round 4/10, elapsed time 58.51
# [IterativeImputer] Ending imputation round 5/10, elapsed time 73.02
# [IterativeImputer] Ending imputation round 6/10, elapsed time 87.64
# [IterativeImputer] Ending imputation round 7/10, elapsed time 102.26
# [IterativeImputer] Ending imputation round 8/10, elapsed time 116.66
# [IterativeImputer] Ending imputation round 9/10, elapsed time 131.10
# [IterativeImputer] Ending imputation round 10/10, elapsed time 145.73
# Imputation round 7
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 14.78
# [IterativeImputer] Ending imputation round 2/10, elapsed time 29.19
# [IterativeImputer] Ending imputation round 3/10, elapsed time 43.77
# [IterativeImputer] Ending imputation round 4/10, elapsed time 58.45
# [IterativeImputer] Ending imputation round 5/10, elapsed time 72.94
# [IterativeImputer] Ending imputation round 6/10, elapsed time 87.48
# [IterativeImputer] Ending imputation round 7/10, elapsed time 102.02
# [IterativeImputer] Ending imputation round 8/10, elapsed time 116.99
# [IterativeImputer] Ending imputation round 9/10, elapsed time 131.61
# [IterativeImputer] Ending imputation round 10/10, elapsed time 146.23
# Imputation round 8
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 14.53
# [IterativeImputer] Ending imputation round 2/10, elapsed time 29.04
# [IterativeImputer] Ending imputation round 3/10, elapsed time 43.74
# [IterativeImputer] Ending imputation round 4/10, elapsed time 58.22
# [IterativeImputer] Ending imputation round 5/10, elapsed time 72.84
# [IterativeImputer] Ending imputation round 6/10, elapsed time 87.46
# [IterativeImputer] Ending imputation round 7/10, elapsed time 102.30
# [IterativeImputer] Ending imputation round 8/10, elapsed time 116.75
# [IterativeImputer] Ending imputation round 9/10, elapsed time 131.42
# [IterativeImputer] Ending imputation round 10/10, elapsed time 145.93
# Imputation round 9
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 14.72
# [IterativeImputer] Ending imputation round 2/10, elapsed time 29.34
# [IterativeImputer] Ending imputation round 3/10, elapsed time 44.10
# [IterativeImputer] Ending imputation round 4/10, elapsed time 58.66
# [IterativeImputer] Ending imputation round 5/10, elapsed time 73.72
# [IterativeImputer] Ending imputation round 6/10, elapsed time 88.48
# [IterativeImputer] Ending imputation round 7/10, elapsed time 102.85
# [IterativeImputer] Ending imputation round 8/10, elapsed time 117.35
# [IterativeImputer] Ending imputation round 9/10, elapsed time 132.00
# [IterativeImputer] Ending imputation round 10/10, elapsed time 146.60
# Imputation round 10
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 14.41
# [IterativeImputer] Ending imputation round 2/10, elapsed time 28.99
# [IterativeImputer] Ending imputation round 3/10, elapsed time 43.67
# [IterativeImputer] Ending imputation round 4/10, elapsed time 58.12
# [IterativeImputer] Ending imputation round 5/10, elapsed time 72.65
# [IterativeImputer] Ending imputation round 6/10, elapsed time 87.15
# [IterativeImputer] Ending imputation round 7/10, elapsed time 101.75
# [IterativeImputer] Ending imputation round 8/10, elapsed time 116.45
# [IterativeImputer] Ending imputation round 9/10, elapsed time 130.93
# [IterativeImputer] Ending imputation round 10/10, elapsed time 145.44
# Imputation round 11
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 14.71
# [IterativeImputer] Ending imputation round 2/10, elapsed time 29.27
# [IterativeImputer] Ending imputation round 3/10, elapsed time 43.97
# [IterativeImputer] Ending imputation round 4/10, elapsed time 58.60
# [IterativeImputer] Ending imputation round 5/10, elapsed time 73.12
# [IterativeImputer] Ending imputation round 6/10, elapsed time 87.62
# [IterativeImputer] Ending imputation round 7/10, elapsed time 102.19
# [IterativeImputer] Ending imputation round 8/10, elapsed time 116.65
# [IterativeImputer] Ending imputation round 9/10, elapsed time 131.27
# [IterativeImputer] Ending imputation round 10/10, elapsed time 146.06
# Mit dieser Methode bleiben 0 NaNs bestehen.
#
# 12773 Werte wurden für die Metriken verwendet.
# r2: 0.9885943576738094, rmse: 0.18233283783033039
# Mit dieser Methode bleiben 0 NaNs bestehen.
#
# 12773 Werte wurden für die Metriken verwendet.
# r2: 0.06481901246817201, rmse: 1.6510219673486435
# Mit dieser Methode bleiben 0 NaNs bestehen.
#
# 12773 Werte wurden für die Metriken verwendet.
# r2: -0.20257451102669655, rmse: 1.8722378226900993

# %%
cords = get_cords(0.1)
results10 = []
# Out:
# Testdaten mit 10.0% fehlenden Werten (absolut: 17030)

# %%
base = reset_base()
train = reset_train(cords)

t0 = time.time()
df= impute_backfill(train) 
t1 = time.time()

t = t1-t0

results10 = evaluate('Backfill', df, t, results)

###mean
base = reset_base()
train = reset_train(cords)

t0 = time.time()
df = impute_overall_means(train)
t1 = time.time()

t = t1-t0
results10 = evaluate('Overall Mean', df, t, results)


base = reset_base()
train = reset_train(cords)

t0 = time.time()
df = impute_yearly_means(train)
t1 = time.time()

t = t1-t0

results10 = evaluate('Yearly Mean', df, t, results)


base = reset_base()
train = reset_train(cords)

t0 = time.time()
df = impute_yearly_means_per_region(train)
t1 = time.time()

t = t1-t0

results10 = evaluate('Yearly Mean per Region', df, t, results)

base = reset_base()
train = reset_train(cords)

t0 = time.time()
df = interpolate3(train)
t1 = time.time()

t = t1-t0

results10 = evaluate('Interpolation 3', df, t, results)

base = reset_base()
train = reset_train(cords)

t0 = time.time()
df = interpolate_all(train)
t1 = time.time()

t = t1-t0

results10 = evaluate('Interpolation all', df, t, results)

base = reset_base()
train = reset_train(cords)

t0 = time.time()
df = iterative_imputer_1(train)
t1 = time.time()

t = t1-t0

results10 = evaluate('Iterative Imputer 1', df, t, results)

base = reset_base()
train = reset_train(cords)

t0 = time.time()
df = iterative_imputer_2(train)
t1 = time.time()

t = t1-t0

results10 = evaluate('Iterative Imputer 2', df, t, results)

base = reset_base()
train = reset_train(cords)

t0 = time.time()
df = iterative_imputer_3(train)
t1 = time.time()

t = t1-t0

results10 = evaluate('Iterative Imputer 3', df, t, results)

base = reset_base()
train = reset_train(cords)

t0 = time.time()
df = mice_imputer(train)
t1 = time.time()

t = t1-t0
results10 = evaluate('MICE', df, t, results)

base = reset_base()
train = reset_train(cords)

t0 = time.time()
df = knn_imputer1(train)
t1 = time.time()

t = t1-t0

results10 = evaluate('KNN Imputer 1', df, t, results)

base = reset_base()
train = reset_train(cords)

t0 = time.time()
df = knn_imputer2(train, 4)
t1 = time.time()

t = t1-t0

results10 = evaluate('KNN Imputer 2', df, t, results)
# Out:
# Mit dieser Methode bleiben 33605 NaNs bestehen.
#
# 16462 Werte wurden für die Metriken verwendet.
# r2: -0.043800632990352195, rmse: 2.089040474302827
# Mit dieser Methode bleiben 0 NaNs bestehen.
#
# 17030 Werte wurden für die Metriken verwendet.
# r2: -0.0015874687364016982, rmse: 2.0119672962935047
# Mit dieser Methode bleiben 52772 NaNs bestehen.
#
# 17027 Werte wurden für die Metriken verwendet.
# r2: 0.013454075014286193, rmse: 1.9969783912024721
# Mit dieser Methode bleiben 57448 NaNs bestehen.
#
# 16903 Werte wurden für die Metriken verwendet.
# r2: 0.05990583802688387, rmse: 1.9565294158245126
# Mit dieser Methode bleiben 33638 NaNs bestehen.
#
# 16488 Werte wurden für die Metriken verwendet.
# r2: -0.04342564936248783, rmse: 2.0869887856001283
# Mit dieser Methode bleiben 61 NaNs bestehen.
#
# 17027 Werte wurden für die Metriken verwendet.
# r2: -0.04341923745526266, rmse: 2.053733699351703
# C:\Users\mbfbr\Anaconda3\envs\other\lib\site-packages\sklearn\impute\_iterative.py:699: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Mit dieser Methode bleiben 0 NaNs bestehen.
#
# 17030 Werte wurden für die Metriken verwendet.
# r2: 0.9658526097359531, rmse: 0.37149693504215014
# Mit dieser Methode bleiben 0 NaNs bestehen.
#
# 17030 Werte wurden für die Metriken verwendet.
# r2: 0.9452737170229422, rmse: 0.4702994294809716
# [IterativeImputer] Completing matrix with shape (4898, 165)
# [IterativeImputer] Change: 2.6953462925334884e+16, scaled tolerance: 35084726045503.402
# [IterativeImputer] Change: 1852264431665211.8, scaled tolerance: 35084726045503.402
# [IterativeImputer] Change: 708567246179355.8, scaled tolerance: 35084726045503.402
# [IterativeImputer] Change: 755095640854468.6, scaled tolerance: 35084726045503.402
# [IterativeImputer] Change: 488581155875104.2, scaled tolerance: 35084726045503.402
# [IterativeImputer] Change: 345880135817053.0, scaled tolerance: 35084726045503.402
# [IterativeImputer] Change: 857073520992406.6, scaled tolerance: 35084726045503.402
# [IterativeImputer] Change: 717395896181668.9, scaled tolerance: 35084726045503.402
# [IterativeImputer] Change: 236721273481875.84, scaled tolerance: 35084726045503.402
# [IterativeImputer] Change: 3307009851779245.0, scaled tolerance: 35084726045503.402
# C:\Users\mbfbr\Anaconda3\envs\other\lib\site-packages\sklearn\impute\_iterative.py:699: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Mit dieser Methode bleiben 0 NaNs bestehen.
#
# 17030 Werte wurden für die Metriken verwendet.
# r2: 0.5331569987069713, rmse: 1.3736051240937186
# Imputation round 0
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 15.17
# [IterativeImputer] Ending imputation round 2/10, elapsed time 30.01
# [IterativeImputer] Ending imputation round 3/10, elapsed time 44.76
# [IterativeImputer] Ending imputation round 4/10, elapsed time 59.74
# [IterativeImputer] Ending imputation round 5/10, elapsed time 74.58
# [IterativeImputer] Ending imputation round 6/10, elapsed time 89.62
# [IterativeImputer] Ending imputation round 7/10, elapsed time 104.51
# [IterativeImputer] Ending imputation round 8/10, elapsed time 119.57
# [IterativeImputer] Ending imputation round 9/10, elapsed time 134.50
# [IterativeImputer] Ending imputation round 10/10, elapsed time 149.22
# Imputation round 1
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 15.00
# [IterativeImputer] Ending imputation round 2/10, elapsed time 29.99
# [IterativeImputer] Ending imputation round 3/10, elapsed time 44.84
# [IterativeImputer] Ending imputation round 4/10, elapsed time 59.61
# [IterativeImputer] Ending imputation round 5/10, elapsed time 74.61
# [IterativeImputer] Ending imputation round 6/10, elapsed time 89.47
# [IterativeImputer] Ending imputation round 7/10, elapsed time 104.29
# [IterativeImputer] Ending imputation round 8/10, elapsed time 119.13
# [IterativeImputer] Ending imputation round 9/10, elapsed time 133.92
# [IterativeImputer] Ending imputation round 10/10, elapsed time 148.90
# Imputation round 2
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 14.80
# [IterativeImputer] Ending imputation round 2/10, elapsed time 29.63
# [IterativeImputer] Ending imputation round 3/10, elapsed time 44.57
# [IterativeImputer] Ending imputation round 4/10, elapsed time 59.55
# [IterativeImputer] Ending imputation round 5/10, elapsed time 74.50
# [IterativeImputer] Ending imputation round 6/10, elapsed time 89.34
# [IterativeImputer] Ending imputation round 7/10, elapsed time 104.16
# [IterativeImputer] Ending imputation round 8/10, elapsed time 119.00
# [IterativeImputer] Ending imputation round 9/10, elapsed time 133.81
# [IterativeImputer] Ending imputation round 10/10, elapsed time 148.78
# Imputation round 3
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 14.61
# [IterativeImputer] Ending imputation round 2/10, elapsed time 29.56
# [IterativeImputer] Ending imputation round 3/10, elapsed time 44.43
# [IterativeImputer] Ending imputation round 4/10, elapsed time 59.21
# [IterativeImputer] Ending imputation round 5/10, elapsed time 73.97
# [IterativeImputer] Ending imputation round 6/10, elapsed time 88.86
# [IterativeImputer] Ending imputation round 7/10, elapsed time 103.66
# [IterativeImputer] Ending imputation round 8/10, elapsed time 118.45
# [IterativeImputer] Ending imputation round 9/10, elapsed time 133.42
# [IterativeImputer] Ending imputation round 10/10, elapsed time 148.37
# Imputation round 4
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 14.97
# [IterativeImputer] Ending imputation round 2/10, elapsed time 29.81
# [IterativeImputer] Ending imputation round 3/10, elapsed time 44.73
# [IterativeImputer] Ending imputation round 4/10, elapsed time 59.59
# [IterativeImputer] Ending imputation round 5/10, elapsed time 74.49
# [IterativeImputer] Ending imputation round 6/10, elapsed time 89.34
# [IterativeImputer] Ending imputation round 7/10, elapsed time 104.17
# [IterativeImputer] Ending imputation round 8/10, elapsed time 119.24
# [IterativeImputer] Ending imputation round 9/10, elapsed time 134.17
# [IterativeImputer] Ending imputation round 10/10, elapsed time 149.03
# Imputation round 5
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 14.78
# [IterativeImputer] Ending imputation round 2/10, elapsed time 29.76
# [IterativeImputer] Ending imputation round 3/10, elapsed time 44.50
# [IterativeImputer] Ending imputation round 4/10, elapsed time 59.31
# [IterativeImputer] Ending imputation round 5/10, elapsed time 74.14
# [IterativeImputer] Ending imputation round 6/10, elapsed time 88.93
# [IterativeImputer] Ending imputation round 7/10, elapsed time 104.05
# [IterativeImputer] Ending imputation round 8/10, elapsed time 118.87
# [IterativeImputer] Ending imputation round 9/10, elapsed time 133.65
# [IterativeImputer] Ending imputation round 10/10, elapsed time 148.49
# Imputation round 6
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 14.83
# [IterativeImputer] Ending imputation round 2/10, elapsed time 29.59
# [IterativeImputer] Ending imputation round 3/10, elapsed time 44.85
# [IterativeImputer] Ending imputation round 4/10, elapsed time 59.72
# [IterativeImputer] Ending imputation round 5/10, elapsed time 74.78
# [IterativeImputer] Ending imputation round 6/10, elapsed time 89.54
# [IterativeImputer] Ending imputation round 7/10, elapsed time 104.31
# [IterativeImputer] Ending imputation round 8/10, elapsed time 119.07
# [IterativeImputer] Ending imputation round 9/10, elapsed time 133.75
# [IterativeImputer] Ending imputation round 10/10, elapsed time 148.62
# Imputation round 7
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 14.79
# [IterativeImputer] Ending imputation round 2/10, elapsed time 29.76
# [IterativeImputer] Ending imputation round 3/10, elapsed time 44.88
# [IterativeImputer] Ending imputation round 4/10, elapsed time 59.87
# [IterativeImputer] Ending imputation round 5/10, elapsed time 74.70
# [IterativeImputer] Ending imputation round 6/10, elapsed time 89.48
# [IterativeImputer] Ending imputation round 7/10, elapsed time 104.36
# [IterativeImputer] Ending imputation round 8/10, elapsed time 119.09
# [IterativeImputer] Ending imputation round 9/10, elapsed time 133.88
# [IterativeImputer] Ending imputation round 10/10, elapsed time 148.69
# Imputation round 8
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 14.89
# [IterativeImputer] Ending imputation round 2/10, elapsed time 29.67
# [IterativeImputer] Ending imputation round 3/10, elapsed time 44.66
# [IterativeImputer] Ending imputation round 4/10, elapsed time 59.64
# [IterativeImputer] Ending imputation round 5/10, elapsed time 74.47
# [IterativeImputer] Ending imputation round 6/10, elapsed time 89.23
# [IterativeImputer] Ending imputation round 7/10, elapsed time 104.00
# [IterativeImputer] Ending imputation round 8/10, elapsed time 118.89
# [IterativeImputer] Ending imputation round 9/10, elapsed time 133.75
# [IterativeImputer] Ending imputation round 10/10, elapsed time 148.63
# Imputation round 9
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 14.82
# [IterativeImputer] Ending imputation round 2/10, elapsed time 29.69
# [IterativeImputer] Ending imputation round 3/10, elapsed time 44.76
# [IterativeImputer] Ending imputation round 4/10, elapsed time 59.54
# [IterativeImputer] Ending imputation round 5/10, elapsed time 74.25
# [IterativeImputer] Ending imputation round 6/10, elapsed time 89.12
# [IterativeImputer] Ending imputation round 7/10, elapsed time 103.99
# [IterativeImputer] Ending imputation round 8/10, elapsed time 118.83
# [IterativeImputer] Ending imputation round 9/10, elapsed time 133.39
# [IterativeImputer] Ending imputation round 10/10, elapsed time 148.12
# Imputation round 10
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 14.69
# [IterativeImputer] Ending imputation round 2/10, elapsed time 29.58
# [IterativeImputer] Ending imputation round 3/10, elapsed time 44.33
# [IterativeImputer] Ending imputation round 4/10, elapsed time 58.97
# [IterativeImputer] Ending imputation round 5/10, elapsed time 73.90
# [IterativeImputer] Ending imputation round 6/10, elapsed time 88.94
# [IterativeImputer] Ending imputation round 7/10, elapsed time 103.86
# [IterativeImputer] Ending imputation round 8/10, elapsed time 118.82
# [IterativeImputer] Ending imputation round 9/10, elapsed time 133.50
# [IterativeImputer] Ending imputation round 10/10, elapsed time 148.22
# Imputation round 11
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 14.75
# [IterativeImputer] Ending imputation round 2/10, elapsed time 29.50
# [IterativeImputer] Ending imputation round 3/10, elapsed time 44.36
# [IterativeImputer] Ending imputation round 4/10, elapsed time 59.42
# [IterativeImputer] Ending imputation round 5/10, elapsed time 74.24
# [IterativeImputer] Ending imputation round 6/10, elapsed time 88.93
# [IterativeImputer] Ending imputation round 7/10, elapsed time 103.65
# [IterativeImputer] Ending imputation round 8/10, elapsed time 118.32
# [IterativeImputer] Ending imputation round 9/10, elapsed time 133.18
# [IterativeImputer] Ending imputation round 10/10, elapsed time 148.27
# Mit dieser Methode bleiben 0 NaNs bestehen.
#
# 17030 Werte wurden für die Metriken verwendet.
# r2: 0.9921502623704216, rmse: 0.17811645650204147
# Mit dieser Methode bleiben 0 NaNs bestehen.
#
# 17030 Werte wurden für die Metriken verwendet.
# r2: 0.40171197982598716, rmse: 1.555004425815101
# Mit dieser Methode bleiben 0 NaNs bestehen.
#
# 17030 Werte wurden für die Metriken verwendet.
# r2: 0.5164736014860596, rmse: 1.39793368821289

# %% [markdown]
# #### Results

# %%
results = pd.DataFrame(results, columns=['Methode', 'r2', 'RSME', 'Remaining NaNs', 'Time'])
results = results.set_index('Methode')

# %%
results
# Out:
#                                r2      RSME  Remaining NaNs         Time
# Methode
# Backfill               -16.124571  1.683782           32853     0.015625
# Overall Mean            -2.231565  0.720245               0     0.330205
# Yearly Mean             -0.097043  0.419648           52298     0.105673
# Yearly Mean per Region  -0.434978  0.481564           57262     0.251699
# Interpolation 3         -2.959612  0.810691           32884     0.110228
# Interpolation all       -2.959675  0.797266              58     0.046986
# Iterative Imputer 1      0.960905  0.079220               0    10.953229
# Iterative Imputer 2      0.966151  0.073713               0    20.194192
# Iterative Imputer 3      0.662632  0.232716               0    75.957905
# MICE                     0.958887  0.081239               0  1750.670281
# KNN Imputer1             0.294452  0.336540               0   124.328767
# KNN Imputer2             0.970061  0.069326               0    20.023893
# Backfill                -0.613034  2.204393           33291     0.000000
# Overall Mean            -0.079665  1.773984               0     0.329405
# Yearly Mean              0.018307  1.691648           52456     0.100261
# Yearly Mean per Region   0.047509  1.672639           57327     0.235323
# Interpolation 3         -0.160491  1.870855           33321     0.078639
# Interpolation all       -0.160471  1.839171              58     0.064034
# Iterative Imputer 1      0.988734  0.181213               0     9.490769
# Iterative Imputer 2      0.986942  0.195097               0    18.464256
# Iterative Imputer 3      0.934944  0.435459               0    70.915304
# MICE                     0.988594  0.182333               0  1752.888773
# KNN Imputer 1            0.064819  1.651022               0   124.577343
# KNN Imputer 2           -0.202575  1.872238               0    20.128237
# Backfill                -0.043801  2.089040           33605     0.000000
# Overall Mean            -0.001587  2.011967               0     0.297997
# Yearly Mean              0.013454  1.996978           52772     0.093629
# Yearly Mean per Region   0.059906  1.956529           57448     0.203906
# Interpolation 3         -0.043426  2.086989           33638     0.076995
# Interpolation all       -0.043419  2.053734              61     0.047561
# Iterative Imputer 1      0.965853  0.371497               0     9.094873
# Iterative Imputer 2      0.945274  0.470299               0    18.440165
# Iterative Imputer 3      0.533157  1.373605               0    70.267930
# MICE                     0.992150  0.178116               0  1783.928310
# KNN Imputer 1            0.401712  1.555004               0   125.968714
# KNN Imputer 2            0.516474  1.397934               0    20.724534

# %%
results7 = pd.DataFrame(results7, columns=['Methode', 'r2', 'RSME', 'Remaining NaNs', 'Time'])
results7 = results7.set_index('Methode')
results7
# Out:
#                                r2      RSME  Remaining NaNs         Time
# Methode
# Backfill               -16.124571  1.683782           32853     0.015625
# Overall Mean            -2.231565  0.720245               0     0.330205
# Yearly Mean             -0.097043  0.419648           52298     0.105673
# Yearly Mean per Region  -0.434978  0.481564           57262     0.251699
# Interpolation 3         -2.959612  0.810691           32884     0.110228
# Interpolation all       -2.959675  0.797266              58     0.046986
# Iterative Imputer 1      0.960905  0.079220               0    10.953229
# Iterative Imputer 2      0.966151  0.073713               0    20.194192
# Iterative Imputer 3      0.662632  0.232716               0    75.957905
# MICE                     0.958887  0.081239               0  1750.670281
# KNN Imputer1             0.294452  0.336540               0   124.328767
# KNN Imputer2             0.970061  0.069326               0    20.023893
# Backfill                -0.613034  2.204393           33291     0.000000
# Overall Mean            -0.079665  1.773984               0     0.329405
# Yearly Mean              0.018307  1.691648           52456     0.100261
# Yearly Mean per Region   0.047509  1.672639           57327     0.235323
# Interpolation 3         -0.160491  1.870855           33321     0.078639
# Interpolation all       -0.160471  1.839171              58     0.064034
# Iterative Imputer 1      0.988734  0.181213               0     9.490769
# Iterative Imputer 2      0.986942  0.195097               0    18.464256
# Iterative Imputer 3      0.934944  0.435459               0    70.915304
# MICE                     0.988594  0.182333               0  1752.888773
# KNN Imputer 1            0.064819  1.651022               0   124.577343
# KNN Imputer 2           -0.202575  1.872238               0    20.128237
# Backfill                -0.043801  2.089040           33605     0.000000
# Overall Mean            -0.001587  2.011967               0     0.297997
# Yearly Mean              0.013454  1.996978           52772     0.093629
# Yearly Mean per Region   0.059906  1.956529           57448     0.203906
# Interpolation 3         -0.043426  2.086989           33638     0.076995
# Interpolation all       -0.043419  2.053734              61     0.047561
# Iterative Imputer 1      0.965853  0.371497               0     9.094873
# Iterative Imputer 2      0.945274  0.470299               0    18.440165
# Iterative Imputer 3      0.533157  1.373605               0    70.267930
# MICE                     0.992150  0.178116               0  1783.928310
# KNN Imputer 1            0.401712  1.555004               0   125.968714
# KNN Imputer 2            0.516474  1.397934               0    20.724534

# %%
results10 = pd.DataFrame(results10, columns=['Methode', 'r2', 'RSME', 'Remaining NaNs', 'Time'])
results10 = results10.set_index('Methode')
results10
# Out:
#                                r2      RSME  Remaining NaNs         Time
# Methode
# Backfill               -16.124571  1.683782           32853     0.015625
# Overall Mean            -2.231565  0.720245               0     0.330205
# Yearly Mean             -0.097043  0.419648           52298     0.105673
# Yearly Mean per Region  -0.434978  0.481564           57262     0.251699
# Interpolation 3         -2.959612  0.810691           32884     0.110228
# Interpolation all       -2.959675  0.797266              58     0.046986
# Iterative Imputer 1      0.960905  0.079220               0    10.953229
# Iterative Imputer 2      0.966151  0.073713               0    20.194192
# Iterative Imputer 3      0.662632  0.232716               0    75.957905
# MICE                     0.958887  0.081239               0  1750.670281
# KNN Imputer1             0.294452  0.336540               0   124.328767
# KNN Imputer2             0.970061  0.069326               0    20.023893
# Backfill                -0.613034  2.204393           33291     0.000000
# Overall Mean            -0.079665  1.773984               0     0.329405
# Yearly Mean              0.018307  1.691648           52456     0.100261
# Yearly Mean per Region   0.047509  1.672639           57327     0.235323
# Interpolation 3         -0.160491  1.870855           33321     0.078639
# Interpolation all       -0.160471  1.839171              58     0.064034
# Iterative Imputer 1      0.988734  0.181213               0     9.490769
# Iterative Imputer 2      0.986942  0.195097               0    18.464256
# Iterative Imputer 3      0.934944  0.435459               0    70.915304
# MICE                     0.988594  0.182333               0  1752.888773
# KNN Imputer 1            0.064819  1.651022               0   124.577343
# KNN Imputer 2           -0.202575  1.872238               0    20.128237
# Backfill                -0.043801  2.089040           33605     0.000000
# Overall Mean            -0.001587  2.011967               0     0.297997
# Yearly Mean              0.013454  1.996978           52772     0.093629
# Yearly Mean per Region   0.059906  1.956529           57448     0.203906
# Interpolation 3         -0.043426  2.086989           33638     0.076995
# Interpolation all       -0.043419  2.053734              61     0.047561
# Iterative Imputer 1      0.965853  0.371497               0     9.094873
# Iterative Imputer 2      0.945274  0.470299               0    18.440165
# Iterative Imputer 3      0.533157  1.373605               0    70.267930
# MICE                     0.992150  0.178116               0  1783.928310
# KNN Imputer 1            0.401712  1.555004               0   125.968714
# KNN Imputer 2            0.516474  1.397934               0    20.724534
