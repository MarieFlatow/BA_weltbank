# %% [markdown]
# # Experiment

# %% [markdown]
# Hier werden die Ausreißer in den Ergebnissen der 3% Durchläufe untersucht. Hierfür werden ausgewählte Imputationverfahren evaluiert, ohne sie vorher zu scalieren.

# %% [markdown]
# ### Vorbereitung

# %%
import pandas as pd
import numpy as np
import time
import math
from sklearn.metrics import r2_score, mean_squared_error

import experiment
from imputer import *

# %%
t0 = time.time()
results = []
base = experiment.reset_base()

# %%
functions =  {'Backfill':impute_backfill, 'Overall Mean':impute_overall_means, 
              'Yearly Mean':impute_yearly_means, 'Yearly Mean per Region':impute_yearly_means_per_region, 
              'Interpolate 3':interpolate3, 'Interpolate all':interpolate_all, 
              'ICE 3':iterative_imputer3, 'KNN 2':knn_imputer2
             }

# %%
def evaluate(df, t, cords):
    # scaling original data and imputed data
    train = experiment.reset_train(cords)
    #scaler = StandardScaler().fit(train)  # fitting on train?
    #norm_base = pd.DataFrame(scaler.transform(base))
    norm_base = pd.DataFrame(base)
    #df = pd.DataFrame(scaler.transform(df))

    # getting imputed values for simulated NaNs and true value
    res = pd.DataFrame({'y_true': [norm_base.iloc[cords[0][i], cords[1][i]] for i in cords.index],
                        'y_pred': [df.iloc[cords[0][i], cords[1][i]] for i in cords.index]
                        })
    res = res.dropna()

    # calculate evaluation metrics
    r2 = r2_score(res['y_true'], res['y_pred'])
    rmse = math.sqrt(mean_squared_error(res['y_true'], res['y_pred']))
    still_missing = df.isna().sum().sum()

    print(f'r2: {r2}, rmse: {rmse}, t: {t}')
    print('')

    return [r2, rmse, still_missing, t]

# %%
def run_all(frac):
    
    #getting n different training sets
    cords_list =[]
    n = 7
    for i in np.arange(1,n+1):
        cords_list.append(experiment.get_cords(frac, i))
    
    #setting up two dictionaries to save detailed and averaged results
    detailed_results = {}   
    results = {}
         
    #itterating over dictionary of all imputers
    for name, func in functions.items():
        func_runs1 = []
        func_runs2 = []
        print(name)
        
        #running each imputer n times on different training sets
        for count, cords in enumerate(cords_list):            
            print(f'run: {count+1}/{n}')
            
            #running current imputer and timeing runtime
            t0 = time.time()
            df= func(experiment.reset_train(cords)) 
            t1 = time.time()
            t = t1-t0
            
            #evaluating run
            func_runs1.append(evaluate(df, t, cords))
            func_runs2.append(experiment.evaluate(df, t, cords))
        
        #print evaluation result of all runs of current imputer
        print(func_runs1)
        print(func_runs2)
        print ('')
        
        #save detailed and averaged results
        detailed_results[name] = func_runs1
        results[name] = np.mean(np.array(func_runs1), axis=0)
        
    return results, detailed_results

# %% [markdown]
# ### Durchlauf mit 3% fehlenden Werten

# %%
r1, r1_detail = run_all(0.03)
# Out:
# Testdaten mit 3.0% fehlenden Werten (absolut: 5109)
# Testdaten mit 3.0% fehlenden Werten (absolut: 5109)
# Testdaten mit 3.0% fehlenden Werten (absolut: 5109)
# Testdaten mit 3.0% fehlenden Werten (absolut: 5109)
# Testdaten mit 3.0% fehlenden Werten (absolut: 5109)
# Testdaten mit 3.0% fehlenden Werten (absolut: 5109)
# Testdaten mit 3.0% fehlenden Werten (absolut: 5109)
# Backfill
# run: 1/7
# r2: 0.9964693249333287, rmse: 917098994403.9623, t: 1.2889063358306885
#
# r2: 0.9937039221729441, rmse: 0.007707057811487927, t: 1.2889063358306885
#
# run: 2/7
# r2: 0.9703683283858512, rmse: 2705970651798.2363, t: 1.3806488513946533
#
# r2: 0.9657391810107668, rmse: 0.10555221815029571, t: 1.3806488513946533
#
# run: 3/7
# r2: 0.9910573481070527, rmse: 1097877416483.2795, t: 1.3330531120300293
#                        6  0.998732  2.639074e+12       112651.0    3.799003
# ICE 3                  0  0.872523  5.388007e+12            0.0  159.674723
#                        1  0.809526  1.652555e+13            0.0  155.504384
#                        2  0.469080  8.259497e+12            0.0  156.201108
#                        3  0.612651  7.313808e+12            0.0  158.316629
#                        4  0.887273  2.264241e+13            0.0  160.366269
#                        5  0.981930  6.017265e+12            0.0  155.005319
#                        6  0.969725  1.261653e+13            0.0  153.478984
# KNN 2                  0  0.014591  1.498032e+13            0.0   41.468029
#                        1  0.832800  1.548306e+13            0.0   43.928760
#                        2 -0.907432  1.565538e+13            0.0   43.443198
#                        3 -2.715622  2.265209e+13            0.0   47.407870
#                        4  0.320335  5.559753e+13            0.0   44.027094
#                        5 -1.137953  6.545142e+13            0.0   44.247012
#                        6  0.079915  6.955279e+13            0.0   45.445099

# %% [markdown]
# ### Durchlauf mit 5% fehlenden Werten

# %%
r2 , r2_detail =  run_all(0.05)
# Out:
# Testdaten mit 5.0% fehlenden Werten (absolut: 8515)
# Testdaten mit 5.0% fehlenden Werten (absolut: 8515)
# Testdaten mit 5.0% fehlenden Werten (absolut: 8515)
# Testdaten mit 5.0% fehlenden Werten (absolut: 8515)
# Testdaten mit 5.0% fehlenden Werten (absolut: 8515)
# Testdaten mit 5.0% fehlenden Werten (absolut: 8515)
# Testdaten mit 5.0% fehlenden Werten (absolut: 8515)
# Backfill
# run: 1/7
# r2: 0.9503530314485333, rmse: 17021310884426.996, t: 1.455603837966919
#
# r2: 0.9955395119500975, rmse: 0.1861136671230279, t: 1.455603837966919
#
# run: 2/7
# r2: 0.9809521867801201, rmse: 5928783971332.182, t: 1.9820747375488281
#
# r2: 0.9527099134718778, rmse: 0.1345692633962322, t: 1.9820747375488281
#
# run: 3/7
# r2: 0.9903892741110194, rmse: 4751202435314.032, t: 1.9970667362213135
#
# r2: 0.9763782188141665, rmse: 0.09655187044651366, t: 1.9970667362213135
#
# run: 4/7
# r2: 0.9931598463200009, rmse: 3357011513328.415, t: 1.9510610103607178
#
# r2: 0.9821806209292083, rmse: 0.07169457597353222, t: 1.9510610103607178
#
# run: 5/7
# r2: 0.9026648697470671, rmse: 28965231609087.957, t: 1.9854609966278076
#
# r2: 0.9919133372286484, rmse: 0.30785394825052304, t: 1.9854609966278076
#
# run: 6/7
# r2: 0.8976117602114339, rmse: 10277020336666.623, t: 1.9755165576934814
#
# r2: 0.9731047056590749, rmse: 0.11202481252411967, t: 1.9755165576934814
#
# run: 7/7
# r2: 0.9234714005155518, rmse: 27820802256546.39, t: 1.9969563484191895
#
# r2: 0.9555658812117589, rmse: 0.1250581475259366, t: 1.9969563484191895
#
# [[0.9503530314485333, 17021310884426.996, 135735, 1.455603837966919], [0.9809521867801201, 5928783971332.182, 135759, 1.9820747375488281], [0.9903892741110194, 4751202435314.032, 135763, 1.9970667362213135], [0.9931598463200009, 3357011513328.415, 135732, 1.9510610103607178], [0.9026648697470671, 28965231609087.957, 135733, 1.9854609966278076], [0.8976117602114339, 10277020336666.623, 135720, 1.9755165576934814], [0.9234714005155518, 27820802256546.39, 135705, 1.9969563484191895]]
# [[0.9955395119500975, 0.1861136671230279, 135735, 1.455603837966919], [0.9527099134718778, 0.1345692633962322, 135759, 1.9820747375488281], [0.9763782188141665, 0.09655187044651366, 135763, 1.9970667362213135], [0.9821806209292083, 0.07169457597353222, 135732, 1.9510610103607178], [0.9919133372286484, 0.30785394825052304, 135733, 1.9854609966278076], [0.9731047056590749, 0.11202481252411967, 135720, 1.9755165576934814], [0.9555658812117589, 0.1250581475259366, 135705, 1.9969563484191895]]
#
# Overall Mean
# run: 1/7
# r2: 0.012101489217315797, rmse: 74363989833283.81, t: 3.14459228515625
#
# r2: 0.05669183393332822, rmse: 2.650681003229776, t: 3.14459228515625
#
# run: 2/7
# r2: -0.02286014001947767, rmse: 42563772302025.07, t: 2.748694658279419
#
# r2: -0.790210449138931, rmse: 0.8095951367197984, t: 2.748694658279419
#
# run: 3/7
# r2: 0.027260342996533016, rmse: 46746450843267.984, t: 2.59688663482666
#
# r2: -0.5532064922337516, rmse: 0.7655085413178896, t: 2.59688663482666
#
# run: 4/7
# r2: 0.005312132409310166, rmse: 381230981386446.8, t: 2.6283488273620605
#
# r2: -0.08997241697067415, rmse: 1.660005510666315, t: 2.6283488273620605
#
# run: 5/7
# r2: 0.008318548138530057, rmse: 90457867226044.17, t: 2.588407278060913
#
# r2: 0.11899286954213151, rmse: 3.143887946324358, t: 2.588407278060913
#
# run: 6/7
# r2: -0.04013463158727615, rmse: 32886954280623.22, t: 2.6135759353637695
#
# r2: -0.47779978526951816, rmse: 0.8128249377753463, t: 2.6135759353637695
#
# run: 7/7
# r2: 0.005810459078082975, rmse: 98238441639133.2, t: 2.5953798294067383
#
# r2: -0.8943240677067767, rmse: 0.7999521611458515, t: 2.5953798294067383
#
# [[0.012101489217315797, 74363989833283.81, 0, 3.14459228515625], [-0.02286014001947767, 42563772302025.07, 0, 2.748694658279419], [0.027260342996533016, 46746450843267.984, 0, 2.59688663482666], [0.005312132409310166, 381230981386446.8, 0, 2.6283488273620605], [0.008318548138530057, 90457867226044.17, 0, 2.588407278060913], [-0.04013463158727615, 32886954280623.22, 0, 2.6135759353637695], [0.005810459078082975, 98238441639133.2, 0, 2.5953798294067383]]
# [[0.05669183393332822, 2.650681003229776, 0, 3.14459228515625], [-0.790210449138931, 0.8095951367197984, 0, 2.748694658279419], [-0.5532064922337516, 0.7655085413178896, 0, 2.59688663482666], [-0.08997241697067415, 1.660005510666315, 0, 2.6283488273620605], [0.11899286954213151, 3.143887946324358, 0, 2.588407278060913], [-0.47779978526951816, 0.8128249377753463, 0, 2.6135759353637695], [-0.8943240677067767, 0.7999521611458515, 0, 2.5953798294067383]]
#
# Yearly Mean
# run: 1/7
# r2: -0.001740814672995361, rmse: 74883166718491.03, t: 2.2118313312530518
#
# r2: 0.008985379178021446, rmse: 2.716881518390128, t: 2.2118313312530518
#
# run: 2/7
# r2: -0.09195012860958096, rmse: 43977788437715.14, t: 2.189586639404297
#
# r2: -0.003551797532680201, rmse: 0.6061578633668843, t: 2.189586639404297
#
# run: 3/7
# r2: 0.035401966298280296, rmse: 46550410870288.31, t: 2.186021566390991
#
# r2: 0.025439472926086615, rmse: 0.6063729937392315, t: 2.186021566390991
#
# run: 4/7
# r2: 0.010598993868696671, rmse: 380216491940124.4, t: 2.2041804790496826
#
# r2: 0.008786868516204138, rmse: 1.5830159814214808, t: 2.2041804790496826
#
# run: 5/7
# r2: -0.006907366393805292, rmse: 91149650508542.44, t: 2.269796848297119
#
# r2: 0.010161858688363168, rmse: 3.332417750576666, t: 2.269796848297119
#
# run: 6/7
# r2: -0.15161425715312915, rmse: 34604485195371.414, t: 2.140284776687622
#
# r2: -0.013008108104267002, rmse: 0.6729699630892442, t: 2.140284776687622
#
# run: 7/7
# r2: 0.007452746891126627, rmse: 98157268748549.19, t: 2.141423463821411
#
# r2: -0.009632962285299973, rmse: 0.5840077870187619, t: 2.141423463821411
#
# [[-0.001740814672995361, 74883166718491.03, 52298, 2.2118313312530518], [-0.09195012860958096, 43977788437715.14, 52298, 2.189586639404297], [0.035401966298280296, 46550410870288.31, 52298, 2.186021566390991], [0.010598993868696671, 380216491940124.4, 52298, 2.2041804790496826], [-0.006907366393805292, 91149650508542.44, 52298, 2.269796848297119], [-0.15161425715312915, 34604485195371.414, 52298, 2.140284776687622], [0.007452746891126627, 98157268748549.19, 52298, 2.141423463821411]]
# [[0.008985379178021446, 2.716881518390128, 52298, 2.2118313312530518], [-0.003551797532680201, 0.6061578633668843, 52298, 2.189586639404297], [0.025439472926086615, 0.6063729937392315, 52298, 2.186021566390991], [0.008786868516204138, 1.5830159814214808, 52298, 2.2041804790496826], [0.010161858688363168, 3.332417750576666, 52298, 2.269796848297119], [-0.013008108104267002, 0.6729699630892442, 52298, 2.140284776687622], [-0.009632962285299973, 0.5840077870187619, 52298, 2.141423463821411]]
#
# Yearly Mean per Region
# run: 1/7
# r2: -0.1558492117260033, rmse: 80698103123042.61, t: 2.424738645553589
#
# r2: 0.04325592511357179, rmse: 2.6781505643266024, t: 2.424738645553589
#
# run: 2/7
# r2: -0.7957564005965814, rmse: 56603062194502.19, t: 2.396908760070801
#
# r2: -0.13393634910990637, rmse: 0.6466340399807717, t: 2.396908760070801
#
# run: 3/7
# r2: 0.11903415090274572, rmse: 44662101416050.35, t: 2.441869020462036
#
# r2: 0.142246061554122, rmse: 0.5711191093358581, t: 2.441869020462036
#
# run: 4/7
# r2: -0.002718422708539281, rmse: 384076893946981.9, t: 2.431899070739746
#
# r2: -0.016969876436254028, rmse: 1.6089384784679224, t: 2.431899070739746
#
# run: 5/7
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 r2 , r2_detail =  run_all(0.05)
#
# Input In [5], in run_all(frac)
#      27     t = t1-t0
#      29     #evaluating run
# ---> 30     func_runs1.append(evaluate(df, t, cords))
#      31     func_runs2.append(experiment.evaluate(df, t, cords))
#      33 #print evaluation result of all runs of current imputer
#
# Input In [4], in evaluate(df, t, cords)
#       1 def evaluate(df, t, cords):
#       2     # scaling original data and imputed data
# ----> 3     train = experiment.reset_train(cords)
#       4     #scaler = StandardScaler().fit(train)  # fitting on train?
#       5     #norm_base = pd.DataFrame(scaler.transform(base))
#       6     norm_base = pd.DataFrame(base)
#
# File ~\Documents\01_Meine_Dokumente\Uni\BA\BA_weltbank\experiment.py:41, in reset_train(cords)
#      39 train = reset_base()
#      40 for i in cords.index:
# ---> 41     train.iloc[cords[0][i], cords[1][i]] = None
#      42 return train
#
# File ~\Anaconda3\envs\other\lib\site-packages\pandas\core\indexing.py:716, in _LocationIndexer.__setitem__(self, key, value)
#     713 self._has_valid_setitem_indexer(key)
#     715 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 716 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File ~\Anaconda3\envs\other\lib\site-packages\pandas\core\indexing.py:1691, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1688 # align and set the values
#    1689 if take_split_path:
#    1690     # We have to operate column-wise
# -> 1691     self._setitem_with_indexer_split_path(indexer, value, name)
#    1692 else:
#    1693     self._setitem_single_block(indexer, value, name)
#
# File ~\Anaconda3\envs\other\lib\site-packages\pandas\core\indexing.py:1784, in _iLocIndexer._setitem_with_indexer_split_path(self, indexer, value, name)
#    1780 else:
#    1781
#    1782     # scalar value
#    1783     for loc in ilocs:
# -> 1784         self._setitem_single_column(loc, value, pi)
#
# File ~\Anaconda3\envs\other\lib\site-packages\pandas\core\indexing.py:1865, in _iLocIndexer._setitem_single_column(self, loc, value, plane_indexer)
#    1854 """
#    1855
#    1856 Parameters
#    (...)
#    1861     The indexer we use for setitem along axis=0.
#    1862 """
#    1863 pi = plane_indexer
# -> 1865 ser = self.obj._ixs(loc, axis=1)
#    1867 # perform the equivalent of a setitem on the info axis
#    1868 # as we have a null slice or a slice with full bounds
#    1869 # which means essentially reassign to the columns of a
#    1870 # multi-dim object
#    1871 # GH#6149 (null slice), GH#10408 (full bounds)
#    1872 if com.is_null_slice(pi) or com.is_full_slice(pi, len(self.obj)):
#
# File ~\Anaconda3\envs\other\lib\site-packages\pandas\core\frame.py:3442, in DataFrame._ixs(self, i, axis)
#    3439 label = self.columns[i]
#    3441 col_mgr = self._mgr.iget(i)
# -> 3442 result = self._box_col_values(col_mgr, i)
#    3444 # this is a cached value, mark it so
#    3445 result._set_as_cached(label, self)
#
# File ~\Anaconda3\envs\other\lib\site-packages\pandas\core\frame.py:3915, in DataFrame._box_col_values(self, values, loc)
#    3913 klass = self._constructor_sliced
#    3914 # We get index=self.index bc values is a SingleDataManager
# -> 3915 return klass(values, name=name, fastpath=True).__finalize__(self)
#
# File ~\Anaconda3\envs\other\lib\site-packages\pandas\core\generic.py:5517, in NDFrame.__finalize__(self, other, method, **kwargs)
#    5512     return com.pipe(self, func, *args, **kwargs)
#    5514 # ----------------------------------------------------------------------
#    5515 # Attribute access
# -> 5517 @final
#    5518 def __finalize__(
#    5519     self: NDFrameT, other, method: str | None = None, **kwargs
#    5520 ) -> NDFrameT:
#    5521     """
#    5522     Propagate metadata from other to self.
#    5523
#    (...)
#    5535            stable across pandas releases.
#    5536     """
#    5537     if isinstance(other, NDFrame):
#
# KeyboardInterrupt:

# %%
r2 = pd.DataFrame(r2).T
r2

# %%
r2_detail = pd.DataFrame(pd.DataFrame(r2_detail).T.stack().to_dict()).T
r2_detail.columns = ['r2', 'rmse', 'still_missing', 't']
r2_detail

# %% [markdown]
# ### Durchlauf mit 10% fehlenden Werten

# %%
r3, r3_detail = run_all(0.1)

# %%
r3 = pd.DataFrame(r3).T
r3

# %%
r3_detail = pd.DataFrame(pd.DataFrame(r3_detail).T.stack().to_dict()).T
r3_detail.columns = ['r2', 'rmse', 'still_missing', 't']
r3_detail

# %% [markdown]
# ### Imputationverfahren auf Originaldatensatz anwenden

# %%
for name, func in functions.items():
    print(name)

    t0 = time.time()
    df= func(experiment.reset_base()) 
    t1 = time.time()
    t = t1-t0

    print(f'{round(t, 2)}s vergangen')
    print('')
    df.to_csv(f'additional_data/imputed_sets/{name}.csv')

# %% [markdown]
# ### Ergebnisse abspeichern

# %%
t1 = time.time()
t = t1-t0
print(f'comlete runtime: {t/60}min')

# %%
sets = {'r1':r1, 'r1_detail':r1_detail,
       'r2':r2, 'r2_detail':r2_detail,
       'r3':r3, 'r3_detail':r3_detail,}
for name, df in sets.items():
    df.to_csv(f'additional_data/results/{name}.csv')
