# %%
import pandas as pd
import numpy as np
import time

import experiment
from imputer import *

# %%
t0 = time.time()
results = []
#base, scaler = experiment.reset_base(scaled=scaled, return_scaler=True)

# %%
functions =  {'Backfill':impute_backfill, 'Overall Mean':impute_overall_means, 
              'Yearly Mean':impute_yearly_means, 'Yearly Mean per Region':impute_yearly_means_per_region, 
              'Interpolate 3':interpolate3, 'Interpolate all':interpolate_all, 
              'ICE 1':iterative_imputer1, 'ICE 2':iterative_imputer2, 
              'ICE 3':iterative_imputer3, 'MICE 1':mice_imputer, 'MICE 2':mice_imputer2, 
              'KNN 1':knn_imputer1, 'KNN 2':knn_imputer2
             }

# %%
scaled=True
for name, func in functions.items():
    print(name)
    
    #impute original (scaled) dataset
    t0 = time.time()
    base, scaler = experiment.reset_base(scaled=scaled, return_scaler=True)
    df= func(base) 
    t1 = time.time()
    t = t1-t0
    
    #rescale to original proportions
    col = df.columns
    idx = df.index
    df = scaler.inverse_transform(df)
    df = pd.DataFrame(df, columns=col, index=idx)

    print(f'{round(t, 2)}s vergangen')
    print('')
    df.to_csv(f'additional_data/imputed_sets/scaled/{name}.csv')
# Out:
# Backfill
# 0.22s vergangen
#
# Overall Mean
# 0.56s vergangen
#
# Yearly Mean
# 0.28s vergangen
#
# Yearly Mean per Region
# 0.42s vergangen
#
# Interpolate 3
# 2.26s vergangen
#
# Interpolate all
# 1.51s vergangen
#
# ICE 1
# C:\Users\schwa\anaconda3\lib\site-packages\sklearn\impute\_iterative.py:699: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# 12.96s vergangen
#
# ICE 2
# C:\Users\schwa\anaconda3\lib\site-packages\sklearn\impute\_iterative.py:699: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# 103.82s vergangen
#
# ICE 3
# [IterativeImputer] Completing matrix with shape (4898, 165)
# [IterativeImputer] Change: 98.86652185477122, scaled tolerance: 0.11370298835951696
# [IterativeImputer] Change: 300.9499313595279, scaled tolerance: 0.11370298835951696
# [IterativeImputer] Change: 335.0402796084985, scaled tolerance: 0.11370298835951696
# [IterativeImputer] Change: 85.62030138511601, scaled tolerance: 0.11370298835951696
# [IterativeImputer] Change: 1316.7388692189515, scaled tolerance: 0.11370298835951696
# [IterativeImputer] Change: 860.0137215932846, scaled tolerance: 0.11370298835951696
# [IterativeImputer] Change: 591.9256689911845, scaled tolerance: 0.11370298835951696
# [IterativeImputer] Change: 1691.2582393542325, scaled tolerance: 0.11370298835951696
# [IterativeImputer] Change: 1690.4436131565592, scaled tolerance: 0.11370298835951696
# [IterativeImputer] Change: 641.041467924275, scaled tolerance: 0.11370298835951696
# 98.52s vergangen
# C:\Users\schwa\anaconda3\lib\site-packages\sklearn\impute\_iterative.py:699: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# MICE 1
# Imputation round 1/12
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 1.41
# [IterativeImputer] Ending imputation round 2/10, elapsed time 2.80
# [IterativeImputer] Ending imputation round 3/10, elapsed time 4.18
# [IterativeImputer] Ending imputation round 4/10, elapsed time 5.52
# [IterativeImputer] Ending imputation round 5/10, elapsed time 7.00
# [IterativeImputer] Ending imputation round 6/10, elapsed time 8.37
# [IterativeImputer] Ending imputation round 7/10, elapsed time 9.75
# [IterativeImputer] Ending imputation round 8/10, elapsed time 11.11
# [IterativeImputer] Ending imputation round 9/10, elapsed time 12.50
# [IterativeImputer] Ending imputation round 10/10, elapsed time 13.92
# Imputation round 2/12
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 1.39
# [IterativeImputer] Ending imputation round 2/10, elapsed time 2.82
# [IterativeImputer] Ending imputation round 3/10, elapsed time 4.27
# [IterativeImputer] Ending imputation round 4/10, elapsed time 5.65
# [IterativeImputer] Ending imputation round 5/10, elapsed time 7.07
# [IterativeImputer] Ending imputation round 6/10, elapsed time 8.45
# [IterativeImputer] Ending imputation round 7/10, elapsed time 9.89
# [IterativeImputer] Ending imputation round 8/10, elapsed time 11.29
# [IterativeImputer] Ending imputation round 9/10, elapsed time 12.68
# [IterativeImputer] Ending imputation round 10/10, elapsed time 14.11
# Imputation round 3/12
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 1.42
# [IterativeImputer] Ending imputation round 2/10, elapsed time 2.86
# [IterativeImputer] Ending imputation round 3/10, elapsed time 4.25
# [IterativeImputer] Ending imputation round 4/10, elapsed time 5.67
# [IterativeImputer] Ending imputation round 5/10, elapsed time 7.08
# [IterativeImputer] Ending imputation round 6/10, elapsed time 8.46
# [IterativeImputer] Ending imputation round 7/10, elapsed time 9.86
# [IterativeImputer] Ending imputation round 8/10, elapsed time 11.21
# [IterativeImputer] Ending imputation round 9/10, elapsed time 12.62
# [IterativeImputer] Ending imputation round 10/10, elapsed time 14.02
# Imputation round 4/12
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 1.43
# [IterativeImputer] Ending imputation round 2/10, elapsed time 2.90
# [IterativeImputer] Ending imputation round 3/10, elapsed time 4.34
# [IterativeImputer] Ending imputation round 4/10, elapsed time 5.81
# [IterativeImputer] Ending imputation round 5/10, elapsed time 7.26
# [IterativeImputer] Ending imputation round 6/10, elapsed time 8.66
# [IterativeImputer] Ending imputation round 7/10, elapsed time 10.07
# [IterativeImputer] Ending imputation round 8/10, elapsed time 11.46
# [IterativeImputer] Ending imputation round 9/10, elapsed time 12.95
# [IterativeImputer] Ending imputation round 10/10, elapsed time 14.37
# Imputation round 5/12
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 1.38
# [IterativeImputer] Ending imputation round 2/10, elapsed time 2.78
# [IterativeImputer] Ending imputation round 3/10, elapsed time 4.18
# [IterativeImputer] Ending imputation round 4/10, elapsed time 5.65
# [IterativeImputer] Ending imputation round 5/10, elapsed time 7.06
# [IterativeImputer] Ending imputation round 6/10, elapsed time 8.48
# [IterativeImputer] Ending imputation round 7/10, elapsed time 9.94
# [IterativeImputer] Ending imputation round 8/10, elapsed time 11.35
# [IterativeImputer] Ending imputation round 9/10, elapsed time 12.75
# [IterativeImputer] Ending imputation round 10/10, elapsed time 14.15
# Imputation round 6/12
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 1.39
# [IterativeImputer] Ending imputation round 2/10, elapsed time 2.82
# [IterativeImputer] Ending imputation round 3/10, elapsed time 4.19
# [IterativeImputer] Ending imputation round 4/10, elapsed time 5.63
# [IterativeImputer] Ending imputation round 5/10, elapsed time 7.06
# [IterativeImputer] Ending imputation round 6/10, elapsed time 8.51
# [IterativeImputer] Ending imputation round 7/10, elapsed time 9.96
# [IterativeImputer] Ending imputation round 8/10, elapsed time 11.35
# [IterativeImputer] Ending imputation round 9/10, elapsed time 12.77
# [IterativeImputer] Ending imputation round 10/10, elapsed time 14.20
# Imputation round 7/12
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 1.39
# [IterativeImputer] Ending imputation round 2/10, elapsed time 2.82
# [IterativeImputer] Ending imputation round 3/10, elapsed time 4.26
# [IterativeImputer] Ending imputation round 4/10, elapsed time 5.72
# [IterativeImputer] Ending imputation round 5/10, elapsed time 7.18
# [IterativeImputer] Ending imputation round 6/10, elapsed time 8.54
# [IterativeImputer] Ending imputation round 7/10, elapsed time 9.95
# [IterativeImputer] Ending imputation round 8/10, elapsed time 11.35
# [IterativeImputer] Ending imputation round 9/10, elapsed time 12.83
# [IterativeImputer] Ending imputation round 10/10, elapsed time 14.24
# Imputation round 8/12
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 1.37
# [IterativeImputer] Ending imputation round 2/10, elapsed time 2.87
# [IterativeImputer] Ending imputation round 3/10, elapsed time 4.30
# [IterativeImputer] Ending imputation round 4/10, elapsed time 5.76
# [IterativeImputer] Ending imputation round 5/10, elapsed time 7.22
# [IterativeImputer] Ending imputation round 6/10, elapsed time 8.62
# [IterativeImputer] Ending imputation round 7/10, elapsed time 10.05
# [IterativeImputer] Ending imputation round 8/10, elapsed time 11.39
# [IterativeImputer] Ending imputation round 9/10, elapsed time 12.79
# [IterativeImputer] Ending imputation round 10/10, elapsed time 14.19
# Imputation round 9/12
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 1.44
# [IterativeImputer] Ending imputation round 2/10, elapsed time 2.85
# [IterativeImputer] Ending imputation round 3/10, elapsed time 4.25
# [IterativeImputer] Ending imputation round 4/10, elapsed time 5.69
# [IterativeImputer] Ending imputation round 5/10, elapsed time 7.14
# [IterativeImputer] Ending imputation round 6/10, elapsed time 8.58
# [IterativeImputer] Ending imputation round 7/10, elapsed time 10.01
# [IterativeImputer] Ending imputation round 8/10, elapsed time 11.41
# [IterativeImputer] Ending imputation round 9/10, elapsed time 12.82
# [IterativeImputer] Ending imputation round 10/10, elapsed time 14.28
# Imputation round 10/12
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 1.48
# [IterativeImputer] Ending imputation round 2/10, elapsed time 2.88
# [IterativeImputer] Ending imputation round 3/10, elapsed time 4.27
# [IterativeImputer] Ending imputation round 4/10, elapsed time 5.71
# [IterativeImputer] Ending imputation round 5/10, elapsed time 7.12
# [IterativeImputer] Ending imputation round 6/10, elapsed time 8.57
# [IterativeImputer] Ending imputation round 7/10, elapsed time 10.06
# [IterativeImputer] Ending imputation round 8/10, elapsed time 11.46
# [IterativeImputer] Ending imputation round 9/10, elapsed time 12.88
# [IterativeImputer] Ending imputation round 10/10, elapsed time 14.29
# Imputation round 11/12
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 1.37
# [IterativeImputer] Ending imputation round 2/10, elapsed time 2.76
# [IterativeImputer] Ending imputation round 3/10, elapsed time 4.18
# [IterativeImputer] Ending imputation round 4/10, elapsed time 5.62
# [IterativeImputer] Ending imputation round 5/10, elapsed time 7.07
# [IterativeImputer] Ending imputation round 6/10, elapsed time 8.45
# [IterativeImputer] Ending imputation round 7/10, elapsed time 9.89
# [IterativeImputer] Ending imputation round 8/10, elapsed time 11.29
# [IterativeImputer] Ending imputation round 9/10, elapsed time 12.74
# [IterativeImputer] Ending imputation round 10/10, elapsed time 14.14
# Imputation round 12/12
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 1.36
# [IterativeImputer] Ending imputation round 2/10, elapsed time 2.76
# [IterativeImputer] Ending imputation round 3/10, elapsed time 4.15
# [IterativeImputer] Ending imputation round 4/10, elapsed time 5.57
# [IterativeImputer] Ending imputation round 5/10, elapsed time 6.94
# [IterativeImputer] Ending imputation round 6/10, elapsed time 8.32
# [IterativeImputer] Ending imputation round 7/10, elapsed time 9.72
# [IterativeImputer] Ending imputation round 8/10, elapsed time 11.12
# [IterativeImputer] Ending imputation round 9/10, elapsed time 12.65
# [IterativeImputer] Ending imputation round 10/10, elapsed time 14.23
# 170.97s vergangen
#
# MICE 2
# Imputation round 1/5
# [IterativeImputer] Completing matrix with shape (4898, 165)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 10.59
# [IterativeImputer] Ending imputation round 2/10, elapsed time 20.94
# [IterativeImputer] Ending imputation round 3/10, elapsed time 30.89
# [IterativeImputer] Ending imputation round 4/10, elapsed time 40.89
# [IterativeImputer] Ending imputation round 5/10, elapsed time 50.87
# [IterativeImputer] Ending imputation round 6/10, elapsed time 61.01
# [IterativeImputer] Ending imputation round 7/10, elapsed time 71.08
# [IterativeImputer] Ending imputation round 8/10, elapsed time 81.38
# [IterativeImputer] Ending imputation round 9/10, elapsed time 91.74
# [IterativeImputer] Ending imputation round 10/10, elapsed time 102.22
# Imputation round 2/5
# [IterativeImputer] Completing matrix with shape (4898, 165)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 10.24
# [IterativeImputer] Ending imputation round 2/10, elapsed time 20.55
# [IterativeImputer] Ending imputation round 3/10, elapsed time 31.73
# [IterativeImputer] Ending imputation round 4/10, elapsed time 42.60
# [IterativeImputer] Ending imputation round 5/10, elapsed time 53.00
# [IterativeImputer] Ending imputation round 6/10, elapsed time 63.20
# [IterativeImputer] Ending imputation round 7/10, elapsed time 73.50
# [IterativeImputer] Ending imputation round 8/10, elapsed time 84.21
# [IterativeImputer] Ending imputation round 9/10, elapsed time 95.58
# [IterativeImputer] Ending imputation round 10/10, elapsed time 107.14
# Imputation round 3/5
# [IterativeImputer] Completing matrix with shape (4898, 165)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 10.07
# [IterativeImputer] Ending imputation round 2/10, elapsed time 20.16
# [IterativeImputer] Ending imputation round 3/10, elapsed time 30.25
# [IterativeImputer] Ending imputation round 4/10, elapsed time 40.29
# [IterativeImputer] Ending imputation round 5/10, elapsed time 50.52
# [IterativeImputer] Ending imputation round 6/10, elapsed time 60.74
# [IterativeImputer] Ending imputation round 7/10, elapsed time 71.00
# [IterativeImputer] Ending imputation round 8/10, elapsed time 81.35
# [IterativeImputer] Ending imputation round 9/10, elapsed time 91.72
# [IterativeImputer] Ending imputation round 10/10, elapsed time 102.82
# Imputation round 4/5
# [IterativeImputer] Completing matrix with shape (4898, 165)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 10.00
# [IterativeImputer] Ending imputation round 2/10, elapsed time 20.40
# [IterativeImputer] Ending imputation round 3/10, elapsed time 30.69
# [IterativeImputer] Ending imputation round 4/10, elapsed time 41.06
# [IterativeImputer] Ending imputation round 5/10, elapsed time 51.44
# [IterativeImputer] Ending imputation round 6/10, elapsed time 61.80
# [IterativeImputer] Ending imputation round 7/10, elapsed time 72.34
# [IterativeImputer] Ending imputation round 8/10, elapsed time 82.59
# [IterativeImputer] Ending imputation round 9/10, elapsed time 93.10
# [IterativeImputer] Ending imputation round 10/10, elapsed time 104.84
# Imputation round 5/5
# [IterativeImputer] Completing matrix with shape (4898, 165)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 10.08
# [IterativeImputer] Ending imputation round 2/10, elapsed time 20.45
# [IterativeImputer] Ending imputation round 3/10, elapsed time 30.66
# [IterativeImputer] Ending imputation round 4/10, elapsed time 40.87
# [IterativeImputer] Ending imputation round 5/10, elapsed time 50.87
# [IterativeImputer] Ending imputation round 6/10, elapsed time 61.09
# [IterativeImputer] Ending imputation round 7/10, elapsed time 71.21
# [IterativeImputer] Ending imputation round 8/10, elapsed time 82.16
# [IterativeImputer] Ending imputation round 9/10, elapsed time 93.78
# [IterativeImputer] Ending imputation round 10/10, elapsed time 105.42
# 523.23s vergangen
#
# KNN 1
# 111.03s vergangen
#
# KNN 2
# 18.12s vergangen

# %%
scaled=False
for name, func in functions.items():
    print(name)
    
    #impute original (scaled) dataset
    t0 = time.time()
    df= func(experiment.reset_base(scaled=scaled)) 
    t1 = time.time()
    t = t1-t0

    print(f'{round(t, 2)}s vergangen')
    print('')
    df.to_csv(f'additional_data/imputed_sets/unscaled/{name}.csv')
# Out:
# Backfill
# 0.17s vergangen
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21148\893485113.py in <module>
#      11     print(f'{round(t, 2)}s vergangen')
#      12     print('')
# ---> 13     df.to_csv(f'additional_data/imputed_sets/unscaled/{name}.csv')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3549         )
#    3550
# -> 3551         return DataFrameRenderer(formatter).to_csv(
#    3552             path_or_buf,
#    3553             line_terminator=line_terminator,
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1178             formatter=self.fmt,
#    1179         )
# -> 1180         csv_formatter.save()
#    1181
#    1182         if created_buffer:
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     239         """
#     240         # apply compression and byte/text conversion
# --> 241         with get_handle(
#     242             self.filepath_or_buffer,
#     243             self.mode,
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     692     # Only for write methods
#     693     if "r" not in mode and is_path:
# --> 694         check_parent_directory(str(handle))
#     695
#     696     if compression:
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in check_parent_directory(path)
#     566     parent = Path(path).parent
#     567     if not parent.is_dir():
# --> 568         raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#     569
#     570
#
# OSError: Cannot save file into a non-existent directory: 'additional_data\imputed_sets\unscaled'
