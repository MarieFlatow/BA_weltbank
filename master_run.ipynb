# %% [markdown]
# # Vergleich von Imputation Methoden

# %% [markdown]
# An dieser Stelle sollen verschiede Methoden zum interpolieren von fehlenden Werten betrachtet und verglichen werden.

# %% [markdown]
# ### Vorbereitung

# %%
import pandas as pd
import numpy as np
import math
import time

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer, KNNImputer

# %%
results = []

# %%
def reset_base():
    base= pd.read_csv('additional_data/base.csv') 
    base.set_index(['Country Name', 'Indicator Name'], inplace=True)
    base = base.sort_index(level=['Country Name', 'Indicator Name'])
    return base
base = reset_base()

def get_cords(frac, rnd_state):
    n = int(base.isna().sum().sum()*frac)
    print(f'Testdaten mit {frac*100}% fehlenden Werten (absolut: {n})')
    #random state to ensure reproducibility
    rnds = np.random.RandomState(rnd_state)

    #coordinates for data entries to be removed randomly
    #5000 entries are selected
    cords = pd.DataFrame([[rnds.randint(0, len(base), size=n*4)[i], 
                  rnds.randint(0, len(base.columns), size=n*4)[i]]
                  for i in range(n*4)])

    #all coordinates pointing to NaN entries are removed and
    #first 1000 remaining entries are selected
    cords['value'] = [base.iloc[cords[0][i], cords[1][i]] for i in cords.index]
    cords = cords.dropna()[:n].reset_index(drop=True)
    
    return cords

def reset_train(cords):
    train = reset_base()
    for i in cords.index:
        train.iloc[cords[0][i], cords[1][i]] = None
    return train

def evaluate(df, t, cords):
    
    
    #scaling original data and imputed data
    #necessary ?????????????????????????????????????
    train = reset_train(cords)
    scaler = StandardScaler().fit(train) #fitting on train?
    norm_base = pd.DataFrame(scaler.transform(base))
    df = pd.DataFrame(scaler.transform(df))

    #getting imputed values for simulated NaNs and true value 
    res =pd.DataFrame({'y_true': [norm_base.iloc[cords[0][i], cords[1][i]] for i in cords.index],
                       'y_pred': [df.iloc[cords[0][i], cords[1][i]] for i in cords.index]
                      })
    res = res.dropna()

   
    #calculate evaluation metrics
    r2 = r2_score(res['y_true'], res['y_pred'])
    rmse = math.sqrt(mean_squared_error(res['y_true'], res['y_pred']))
    still_missing = df.isna().sum().sum()
    
    print(f'Mit dieser Methode bleiben {still_missing} NaNs bestehen.')
    print('')
    print(f'{len(res)} Werte wurden für die Metriken verwendet.')
    print(f'r2: {r2}, rmse: {rmse}')
    
    return [r2, rmse, still_missing, t]

# %%
def impute_backfill(df):
    df = df.fillna(method='bfill', limit=3)
    return df

def impute_overall_means(df):
    #fill NaNs with overall mean of that indicator
    values = pd.DataFrame(df.stack()).groupby('Indicator Name')[0].mean()
    df = pd.DataFrame(df.stack(dropna=False))
    
    df[0] = df[0].fillna(df.groupby('Indicator Name')[0].transform('mean'))
    df = df.unstack()
    df.columns = df.columns.droplevel(0)
    df = df.sort_index(level=['Country Name', 'Indicator Name'])
        
    return df

def impute_yearly_means(df):
    #fill NaNs with overall mean of that indicator
    
    for i in df.columns:
        df[i] = df[i].fillna(df.groupby('Indicator Name')[i].transform('mean'))
            
    return df

def impute_yearly_means_per_region(df):
    country_data = pd.read_csv('../Data/WDICountry.csv')
    country_data = country_data.loc[:,['Table Name', 'Region']]
    df = pd.merge(df.reset_index(), country_data, how='left', left_on='Country Name', right_on='Table Name').drop('Table Name', axis=1)
    df = df.set_index(['Country Name', 'Indicator Name', 'Region'])

    for i in df.columns:
        df[i] = df[i].fillna(df.groupby(['Indicator Name', 'Region'])[i].transform('mean'))

    df = df.reset_index().set_index(['Country Name', 'Indicator Name']).drop('Region', axis=1)
    return df

def interpolate3(df):
    df = df.interpolate(limit=3)
    return df

def interpolate_all(df):
    df = df.interpolate()
    return df

def iterative_imputer_1(df):
    col = df.columns
    idx = df.index
    
    iter_imp = IterativeImputer(random_state=999)
    df= iter_imp.fit_transform(df)
    df= pd.DataFrame(df, columns=col, index=idx)
    return df

def iterative_imputer_2(df):
    df = df.unstack().T
    col = df.columns
    idx = df.index

    iter_imp = IterativeImputer(random_state=999)
    df= iter_imp.fit_transform(df)

    df = pd.DataFrame(df, columns=col, index=idx)
    df = df.unstack().T
    df = df.sort_index(level=['Country Name', 'Indicator Name'])
    
    return df

def iterative_imputer_3(df):

    df = df.reset_index()
    df = df.set_index(['Indicator Name', 'Country Name'])
    df = df.unstack().T

    col = df.columns
    idx = df.index

    iter_imp = IterativeImputer(random_state=999, verbose=True)
    df= iter_imp.fit_transform(df)

    df = pd.DataFrame(df, columns=col, index=idx)
    df = df.unstack().T
    df = df.reset_index()
    df = df.set_index(['Country Name', 'Indicator Name'])
    df = df.sort_index(level=['Country Name', 'Indicator Name'])
    
    return df

def mice_imputer(df):
    n_imputations =  12
    dfs = []
    col = df.columns
    idx = df.index
    
    for i in range(n_imputations): 
        print(f'Imputation round {i}')
        iter_imp = IterativeImputer(random_state=i, sample_posterior=True, verbose=2)
        df_temp = iter_imp.fit_transform(df)
        dfs.append(df_temp)
    
    df = np.mean(np.array(dfs), axis=0)
    df = pd.DataFrame(df, columns=col, index=idx)
    return df

def knn_imputer1(df):
    col = df.columns
    idx = df.index
    
    knn_imp = KNNImputer(n_neighbors=2)
    df= knn_imp.fit_transform(df)
    df = pd.DataFrame(df, columns=col, index=idx)
    return df

def knn_imputer2(df, n=4):
    
    df = df.reset_index()
    df = df.set_index(['Indicator Name', 'Country Name'])
    df = df.unstack().T

    col = df.columns
    idx = df.index

    knn_imp = KNNImputer(n_neighbors=n)
    df= knn_imp.fit_transform(df)
    df = pd.DataFrame(df, columns=col, index=idx)

    df = df.unstack().T
    df = df.reset_index()
    df = df.set_index(['Country Name', 'Indicator Name'])
    df = df.sort_index(level=['Country Name', 'Indicator Name'])
    
    return df

# %%
functions =  {'Backfill':impute_backfill, 'Overall Mean':impute_overall_means, 
              'Yearly Mean':impute_yearly_means, 'Yearly Mean per Region':impute_yearly_means_per_region, 
              'Interpolate 3':interpolate3, 'Interpolate all':interpolate_all, 
              'ICE 1':iterative_imputer_1, 'ICE 2':iterative_imputer_2, 
              'ICE3':iterative_imputer_3, 'MICE':mice_imputer, 
              'KNN 1':knn_imputer1, 'KNN 2':knn_imputer2
             }

# %%
def run_all(frac):
    
    cords_list =[]
    for i in np.arange(1,6):
        cords_list.append(get_cords(frac, i))
    
    results = {}
    detailed_results = {}    
    
    for name, func in functions.items():
        func_runs = []
        print(name)
        
        for cords in cords_list:
            
            t0 = time.time()
            df= func(reset_train(cords)) 
            t1 = time.time()

            t = t1-t0

            func_runs.append(evaluate(df, t, cords))
        
        print(func_runs)
        detailed_results[name] = func_runs
        results[name] = np.mean(np.array(func_runs), axis=0)
        
    return results, detailed_results
r1, r1_detail = run_all(0.05)
# Out:
# Testdaten mit 5.0% fehlenden Werten (absolut: 8515)
# Testdaten mit 5.0% fehlenden Werten (absolut: 8515)
# Testdaten mit 5.0% fehlenden Werten (absolut: 8515)
# Testdaten mit 5.0% fehlenden Werten (absolut: 8515)
# Testdaten mit 5.0% fehlenden Werten (absolut: 8515)
# Backfill
# Mit dieser Methode bleiben 32924 NaNs bestehen.
#
# 8195 Werte wurden für die Metriken verwendet.
# r2: -0.2630386067986965, rmse: 3.1264580984032304
# Mit dieser Methode bleiben 32825 NaNs bestehen.
#
# 8263 Werte wurden für die Metriken verwendet.
# r2: -2.77533240911633, rmse: 1.1896157293266358
# Mit dieser Methode bleiben 32824 NaNs bestehen.
#
# 8250 Werte wurden für die Metriken verwendet.
# r2: -1.688280205196218, rmse: 1.0226797653748734
# Mit dieser Methode bleiben 32841 NaNs bestehen.
#
# 8249 Werte wurden für die Metriken verwendet.
# r2: -0.6672076075877178, rmse: 2.085863590967128
# Mit dieser Methode bleiben 32828 NaNs bestehen.
#
# 8240 Werte wurden für die Metriken verwendet.
# r2: -0.07720522781720884, rmse: 3.533882957257935
# [[-0.2630386067986965, 3.1264580984032304, 32924, 0.8470585346221924], [-2.77533240911633, 1.1896157293266358, 32825, 0.8149497509002686], [-1.688280205196218, 1.0226797653748734, 32824, 0.8468687534332275], [-0.6672076075877178, 2.085863590967128, 32841, 0.8312067985534668], [-0.07720522781720884, 3.533882957257935, 32828, 0.8316986560821533]]
# Overall Mean
# Mit dieser Methode bleiben 0 NaNs bestehen.
#
# 8515 Werte wurden für die Metriken verwendet.
# r2: 0.05669183393332822, rmse: 2.650681003229776
# Mit dieser Methode bleiben 0 NaNs bestehen.
#
# 8515 Werte wurden für die Metriken verwendet.
# r2: -0.790210449138931, rmse: 0.8095951367197984
# Mit dieser Methode bleiben 0 NaNs bestehen.
#
# 8515 Werte wurden für die Metriken verwendet.
# r2: -0.5532064922337516, rmse: 0.7655085413178896
# Mit dieser Methode bleiben 0 NaNs bestehen.
#
# 8515 Werte wurden für die Metriken verwendet.
# r2: -0.08997241697067415, rmse: 1.660005510666315
# Mit dieser Methode bleiben 0 NaNs bestehen.
#
# 8515 Werte wurden für die Metriken verwendet.
# r2: 0.11899286954213151, rmse: 3.143887946324358
# [[0.05669183393332822, 2.650681003229776, 0, 1.1132769584655762], [-0.790210449138931, 0.8095951367197984, 0, 1.2713866233825684], [-0.5532064922337516, 0.7655085413178896, 0, 1.1295201778411865], [-0.08997241697067415, 1.660005510666315, 0, 1.1285955905914307], [0.11899286954213151, 3.143887946324358, 0, 1.1141579151153564]]
# Yearly Mean
# Mit dieser Methode bleiben 52298 NaNs bestehen.
#
# 8515 Werte wurden für die Metriken verwendet.
# r2: 0.008985379178021446, rmse: 2.716881518390128
# Mit dieser Methode bleiben 52298 NaNs bestehen.
#
# 8515 Werte wurden für die Metriken verwendet.
# r2: -0.003551797532680201, rmse: 0.6061578633668843
# Mit dieser Methode bleiben 52298 NaNs bestehen.
#
# 8515 Werte wurden für die Metriken verwendet.
# r2: 0.025439472926086615, rmse: 0.6063729937392315
# Mit dieser Methode bleiben 52298 NaNs bestehen.
#
# 8515 Werte wurden für die Metriken verwendet.
# r2: 0.008786868516204138, rmse: 1.5830159814214808
# Mit dieser Methode bleiben 52298 NaNs bestehen.
#
# 8515 Werte wurden für die Metriken verwendet.
# r2: 0.010161858688363168, rmse: 3.332417750576666
# [[0.008985379178021446, 2.716881518390128, 52298, 0.9248874187469482], [-0.003551797532680201, 0.6061578633668843, 52298, 0.9092516899108887], [0.025439472926086615, 0.6063729937392315, 52298, 0.925830602645874], [0.008786868516204138, 1.5830159814214808, 52298, 0.9253294467926025], [0.010161858688363168, 3.332417750576666, 52298, 0.9226090908050537]]
# Yearly Mean per Region
# Mit dieser Methode bleiben 57298 NaNs bestehen.
#
# 8460 Werte wurden für die Metriken verwendet.
# r2: 0.04325592511357179, rmse: 2.6781505643266024
# Mit dieser Methode bleiben 57253 NaNs bestehen.
#
# 8453 Werte wurden für die Metriken verwendet.
# r2: -0.13393634910990637, rmse: 0.6466340399807717
# Mit dieser Methode bleiben 57277 NaNs bestehen.
#
# 8448 Werte wurden für die Metriken verwendet.
# r2: 0.142246061554122, rmse: 0.5711191093358581
# Mit dieser Methode bleiben 57243 NaNs bestehen.
#
# 8457 Werte wurden für die Metriken verwendet.
# r2: -0.016969876436254028, rmse: 1.6089384784679224
# Mit dieser Methode bleiben 57299 NaNs bestehen.
#
# 8460 Werte wurden für die Metriken verwendet.
# r2: 0.04707993810865507, rmse: 3.2802890718166893
# [[0.04325592511357179, 2.6781505643266024, 57298, 1.0414488315582275], [-0.13393634910990637, 0.6466340399807717, 57253, 1.0505421161651611], [0.142246061554122, 0.5711191093358581, 57277, 1.0435638427734375], [-0.016969876436254028, 1.6089384784679224, 57243, 1.0362110137939453], [0.04707993810865507, 3.2802890718166893, 57299, 1.0835316181182861]]
# Interpolate 3
# Mit dieser Methode bleiben 32955 NaNs bestehen.
#
# 8239 Werte wurden für die Metriken verwendet.
# r2: -0.07278844608142343, rmse: 2.8736851665138223
# Mit dieser Methode bleiben 32855 NaNs bestehen.
#
# 8246 Werte wurden für die Metriken verwendet.
# r2: -1.5251093065517671, rmse: 0.9770544483617283
# Mit dieser Methode bleiben 32855 NaNs bestehen.
#
# 8241 Werte wurden für die Metriken verwendet.
# r2: -0.9307057224444135, rmse: 0.8675397097464973
# Mit dieser Methode bleiben 32872 NaNs bestehen.
#
# 8238 Werte wurden für die Metriken verwendet.
# r2: -0.1983244088938556, rmse: 1.7695700053740644
# Mit dieser Methode bleiben 32858 NaNs bestehen.
#
# 8246 Werte wurden für die Metriken verwendet.
# r2: -0.062355380203785726, rmse: 3.508163729433122
# [[-0.07278844608142343, 2.8736851665138223, 32955, 0.9412264823913574], [-1.5251093065517671, 0.9770544483617283, 32855, 0.8944294452667236], [-0.9307057224444135, 0.8675397097464973, 32855, 0.9413132667541504], [-0.1983244088938556, 1.7695700053740644, 32872, 0.9107887744903564], [-0.062355380203785726, 3.508163729433122, 32858, 0.894089937210083]]
# Interpolate all
# Mit dieser Methode bleiben 58 NaNs bestehen.
#
# 8515 Werte wurden für die Metriken verwendet.
# r2: -0.07277380996072114, rmse: 2.8267327446549326
# Mit dieser Methode bleiben 58 NaNs bestehen.
#
# 8515 Werte wurden für die Metriken verwendet.
# r2: -1.5250215404908292, rmse: 0.9614980117285302
# Mit dieser Methode bleiben 58 NaNs bestehen.
#
# 8515 Werte wurden für die Metriken verwendet.
# r2: -0.9308109078094808, rmse: 0.8535035149957807
# Mit dieser Methode bleiben 58 NaNs bestehen.
#
# 8515 Werte wurden für die Metriken verwendet.
# r2: -0.19831645368726547, rmse: 1.7405541422492274
# Mit dieser Methode bleiben 58 NaNs bestehen.
#
# 8515 Werte wurden für die Metriken verwendet.
# r2: -0.062340537018777065, rmse: 3.4523055287879827
# [[-0.07277380996072114, 2.8267327446549326, 58, 0.8779542446136475], [-1.5250215404908292, 0.9614980117285302, 58, 0.8940472602844238], [-0.9308109078094808, 0.8535035149957807, 58, 0.8788530826568604], [-0.19831645368726547, 1.7405541422492274, 58, 0.8626856803894043], [-0.062340537018777065, 3.4523055287879827, 58, 0.8947405815124512]]
# ICE 1
# C:\Users\mbfbr\Anaconda3\envs\other\lib\site-packages\sklearn\impute\_iterative.py:699: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Mit dieser Methode bleiben 0 NaNs bestehen.
#
# 8515 Werte wurden für die Metriken verwendet.
# r2: 0.9942158015767555, rmse: 0.20756410920051788
# C:\Users\mbfbr\Anaconda3\envs\other\lib\site-packages\sklearn\impute\_iterative.py:699: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Mit dieser Methode bleiben 0 NaNs bestehen.
#
# 8515 Werte wurden für die Metriken verwendet.
# r2: 0.7827329900210515, rmse: 0.28204132134606086
# C:\Users\mbfbr\Anaconda3\envs\other\lib\site-packages\sklearn\impute\_iterative.py:699: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Mit dieser Methode bleiben 0 NaNs bestehen.
#
# 8515 Werte wurden für die Metriken verwendet.
# r2: 0.9882365310034197, rmse: 0.06661977296323156
# C:\Users\mbfbr\Anaconda3\envs\other\lib\site-packages\sklearn\impute\_iterative.py:699: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Mit dieser Methode bleiben 0 NaNs bestehen.
#
# 8515 Werte wurden für die Metriken verwendet.
# r2: 0.9877198131046442, rmse: 0.17619933464945803
# C:\Users\mbfbr\Anaconda3\envs\other\lib\site-packages\sklearn\impute\_iterative.py:699: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Mit dieser Methode bleiben 0 NaNs bestehen.
#
# 8515 Werte wurden für die Metriken verwendet.
# r2: 0.
# Mit dieser Methode bleiben 0 NaNs bestehen.
#
# 8515 Werte wurden für die Metriken verwendet.
# r2: 0.3850929761290802, rmse: 2.140106546564469
# Mit dieser Methode bleiben 0 NaNs bestehen.
#
# 8515 Werte wurden für die Metriken verwendet.
# r2: 0.7764619936100474, rmse: 0.28608265888433726
# Mit dieser Methode bleiben 0 NaNs bestehen.
#
# 8515 Werte wurden für die Metriken verwendet.
# r2: 0.018198179415029214, rmse: 0.6086215962503441
# Mit dieser Methode bleiben 0 NaNs bestehen.
#
# 8515 Werte wurden für die Metriken verwendet.
# r2: 0.03975169532798306, rmse: 1.5580936242262533
# Mit dieser Methode bleiben 0 NaNs bestehen.
#
# 8515 Werte wurden für die Metriken verwendet.
# r2: 0.3651864550278935, rmse: 2.6687042009340893
# [[0.3850929761290802, 2.140106546564469, 0, 20.96000051498413], [0.7764619936100474, 0.28608265888433726, 0, 20.700660467147827], [0.018198179415029214, 0.6086215962503441, 0, 20.653963088989258], [0.03975169532798306, 1.5580936242262533, 0, 20.901848316192627], [0.3651864550278935, 2.6687042009340893, 0, 20.401850938796997]]

# %%
r1
# Out:
# {'Backfill': array([-1.09421281e+00,  2.19170003e+00,  3.28484000e+04,  8.34356499e-01]),
#  'Overall Mean': array([-0.25154093,  1.80593563,  0.        ,  1.15138745]),
#  'Yearly Mean': array([9.96435636e-03, 1.76896922e+00, 5.22980000e+04, 9.21581650e-01]),
#  'Yearly Mean per Region': array([1.63351398e-02, 1.75702625e+00, 5.72740000e+04, 1.05105948e+00]),
#  'Interpolate 3': array([-5.57856653e-01,  1.99920261e+00,  3.28790000e+04,  9.16369581e-01]),
#  'Interpolate all': array([-0.55785265,  1.96691879, 58.        ,  0.88165617]),
#  'ICE 1': array([ 0.94874436,  0.2106809 ,  0.        , 10.43908701]),
#  'ICE 2': array([ 0.92646911,  0.44874143,  0.        , 20.39443097]),
#  'ICE3': array([ 0.69647106,  0.93890985,  0.        , 76.07176051]),
#  'MICE': array([9.51523484e-01, 2.36147040e-01, 0.00000000e+00, 1.72219538e+03]),
#  'KNN 1': array([  0.27282434,   1.45838447,   0.        , 123.8936542 ]),
#  'KNN 2': array([ 0.31693826,  1.45232173,  0.        , 20.72366467])}

# %%
r2 , r2_detail =  run_all(0.075)
# Out:
# Testdaten mit 7.5% fehlenden Werten (absolut: 12773)
# Testdaten mit 7.5% fehlenden Werten (absolut: 12773)
# Testdaten mit 7.5% fehlenden Werten (absolut: 12773)
# Testdaten mit 7.5% fehlenden Werten (absolut: 12773)
# Testdaten mit 7.5% fehlenden Werten (absolut: 12773)
# Backfill
# Mit dieser Methode bleiben 33252 NaNs bestehen.
#
# 12384 Werte wurden für die Metriken verwendet.
# r2: -0.7622360204251646, rmse: 1.9101575370444133
# Mit dieser Methode bleiben 33280 NaNs bestehen.
#
# 12322 Werte wurden für die Metriken verwendet.
# r2: -0.13326755926364164, rmse: 1.5732663625326984
# Mit dieser Methode bleiben 33292 NaNs bestehen.
#
# 12334 Werte wurden für die Metriken verwendet.
# r2: -0.15471382925960686, rmse: 2.34729184379117
# Mit dieser Methode bleiben 33312 NaNs bestehen.
#
# 12333 Werte wurden für die Metriken verwendet.
# r2: -0.38762500614250417, rmse: 2.1233606768359277
# Mit dieser Methode bleiben 33191 NaNs bestehen.
#
# 12365 Werte wurden für die Metriken verwendet.
# r2: -0.12638032635757868, rmse: 1.8674634798834449
# [[-0.7622360204251646, 1.9101575370444133, 33252, 1.1781818866729736], [-0.13326755926364164, 1.5732663625326984, 33280, 1.162794828414917], [-0.15471382925960686, 2.34729184379117, 33292, 1.1617162227630615], [-0.38762500614250417, 2.1233606768359277, 33312, 1.1772739887237549], [-0.12638032635757868, 1.8674634798834449, 33191, 1.155029058456421]]
# Overall Mean
# Mit dieser Methode bleiben 0 NaNs bestehen.
#
# 12773 Werte wurden für die Metriken verwendet.
# r2: -0.12238662573392034, rmse: 1.5010550835974847
# Mit dieser Methode bleiben 0 NaNs bestehen.
#
# 12773 Werte wurden für die Metriken verwendet.
# r2: -0.08891407564982123, rmse: 1.5156937528407737
# Mit dieser Methode bleiben 0 NaNs bestehen.
#
# 12773 Werte wurden für die Metriken verwendet.
# r2: 0.03275499935140125, rmse: 2.111408995638594
# Mit dieser Methode bleiben 0 NaNs bestehen.
#
# 12773 Werte wurden für die Metriken verwendet.
# r2: -0.007756779127367608, rmse: 1.7781034777971605
# Mit dieser Methode bleiben 0 NaNs bestehen.
#
# 12773 Werte wurden für die Metriken verwendet.
# r2: -0.07515189456415738, rmse: 1.7956415221980515
# [[-0.12238662573392034, 1.5010550835974847, 0, 1.4600656032562256], [-0.08891407564982123, 1.5156937528407737, 0, 1.4756388664245605], [0.03275499935140125, 2.111408995638594, 0, 1.455134391784668], [-0.007756779127367608, 1.7781034777971605, 0, 1.4753096103668213], [-0.07515189456415738, 1.7956415221980515, 0, 1.4918763637542725]]
# Yearly Mean
# Mit dieser Methode bleiben 52298 NaNs bestehen.
#
# 12773 Werte wurden für die Metriken verwendet.
# r2: 0.01822061654671281, rmse: 1.4038876131419915
# Mit dieser Methode bleiben 52298 NaNs bestehen.
#
# 12773 Werte wurden für die Metriken verwendet.
# r2: 0.02412569603259529, rmse: 1.4348668300371035
# Mit dieser Methode bleiben 52298 NaNs bestehen.
#
# 12773 Werte wurden für die Metriken verwendet.
# r2: 0.0032684411398227198, rmse: 2.143350641743403
# Mit dieser Methode bleiben 52298 NaNs bestehen.
#
# 12773 Werte wurden für die Metriken verwendet.
# r2: 0.018273620856915973, rmse: 1.7549889954672926
# Mit dieser Methode bleiben 52298 NaNs bestehen.
#
# 12773 Werte wurden für die Metriken verwendet.
# r2: 0.009930862430755916, rmse: 1.7231277977735868
# [[0.01822061654671281, 1.4038876131419915, 52298, 1.255314588546753], [0.02412569603259529, 1.4348668300371035, 52298, 1.2409629821777344], [0.0032684411398227198, 2.143350641743403, 52298, 1.239325761795044], [0.018273620856915973, 1.7549889954672926, 52298, 1.2559993267059326], [0.009930862430755916, 1.7231277977735868, 52298, 1.2560112476348877]]
# Yearly Mean per Region
# Mit dieser Methode bleiben 57297 NaNs bestehen.
#
# 12683 Werte wurden für die Metriken verwendet.
# r2: 0.09303613016503465, rmse: 1.3541131516338072
# Mit dieser Methode bleiben 57321 NaNs bestehen.
#
# 12680 Werte wurden für die Metriken verwendet.
# r2: 0.05507454166209702, rmse: 1.4170937274756075
# Mit dieser Methode bleiben 57297 NaNs bestehen.
#
# 12691 Werte wurden für die Metriken verwendet.
# r2: 0.00874238040135733, rmse: 2.144348993401217
# Mit dieser Methode bleiben 57309 NaNs bestehen.
#
# 12698 Werte wurden für die Metriken verwendet.
# r2: 0.06465530405874187, rmse: 1.7180789934399339
# Mit dieser Methode bleiben 57278 NaNs bestehen.
#
# 12691 Werte wurden für die Metriken verwendet.
# r2: 0.023541906379858535, rmse: 1.7167587401913442
# [[0.09303613016503465, 1.3541131516338072, 57297, 1.4298319816589355], [0.05507454166209702, 1.4170937274756075, 57321, 1.365917682647705], [0.00874238040135733, 2.144348993401217, 57297, 1.3658230304718018], [0.06465530405874187, 1.7180789934399339, 57309, 1.3813881874084473], [0.023541906379858535, 1.7167587401913442, 57278, 1.373615026473999]]
# Interpolate 3
# Mit dieser Methode bleiben 33283 NaNs bestehen.
#
# 12334 Werte wurden für die Metriken verwendet.
# r2: -0.2512631805262626, rmse: 1.6128341164139306
# Mit dieser Methode bleiben 33312 NaNs bestehen.
#
# 12371 Werte wurden für die Metriken verwendet.
# r2: -0.24677034897772154, rmse: 1.6479520157944438
# Mit dieser Methode bleiben 33323 NaNs bestehen.
# [IterativeImputer] Ending imputation round 10/10, elapsed time 145.20
# Mit dieser Methode bleiben 0 NaNs bestehen.
#
# 12773 Werte wurden für die Metriken verwendet.
# r2: 0.9852405302779257, rmse: 0.21518626347223285
# Imputation round 0
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 14.45
# [IterativeImputer] Ending imputation round 2/10, elapsed time 28.91
# [IterativeImputer] Ending imputation round 3/10, elapsed time 43.48
# [IterativeImputer] Ending imputation round 4/10, elapsed time 57.98
# [IterativeImputer] Ending imputation round 5/10, elapsed time 72.82
# [IterativeImputer] Ending imputation round 6/10, elapsed time 87.50
# [IterativeImputer] Ending imputation round 7/10, elapsed time 103.24
# [IterativeImputer] Ending imputation round 8/10, elapsed time 117.92
# [IterativeImputer] Ending imputation round 9/10, elapsed time 132.59
# [IterativeImputer] Ending imputation round 10/10, elapsed time 147.27
# Imputation round 1
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 14.55
# [IterativeImputer] Ending imputation round 2/10, elapsed time 29.04
# [IterativeImputer] Ending imputation round 3/10, elapsed time 43.69
# [IterativeImputer] Ending imputation round 4/10, elapsed time 58.17
# [IterativeImputer] Ending imputation round 5/10, elapsed time 73.03
# [IterativeImputer] Ending imputation round 6/10, elapsed time 87.61
# [IterativeImputer] Ending imputation round 7/10, elapsed time 102.17
# [IterativeImputer] Ending imputation round 8/10, elapsed time 116.64
# [IterativeImputer] Ending imputation round 9/10, elapsed time 131.24
# [IterativeImputer] Ending imputation round 10/10, elapsed time 145.94
# Imputation round 2
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 14.56
# [IterativeImputer] Ending imputation round 2/10, elapsed time 28.95
# [IterativeImputer] Ending imputation round 3/10, elapsed time 43.70
# [IterativeImputer] Ending imputation round 4/10, elapsed time 58.36
# [IterativeImputer] Ending imputation round 5/10, elapsed time 73.17
# [IterativeImputer] Ending imputation round 6/10, elapsed time 88.14
# [IterativeImputer] Ending imputation round 7/10, elapsed time 103.33
# [IterativeImputer] Ending imputation round 8/10, elapsed time 119.25
# [IterativeImputer] Ending imputation round 9/10, elapsed time 135.34
# [IterativeImputer] Ending imputation round 10/10, elapsed time 152.62
# Imputation round 3
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 15.08
# [IterativeImputer] Ending imputation round 2/10, elapsed time 29.97
# [IterativeImputer] Ending imputation round 3/10, elapsed time 44.55
# [IterativeImputer] Ending imputation round 4/10, elapsed time 59.36
# [IterativeImputer] Ending imputation round 5/10, elapsed time 74.52
# [IterativeImputer] Ending imputation round 6/10, elapsed time 89.13
# [IterativeImputer] Ending imputation round 7/10, elapsed time 103.94
# [IterativeImputer] Ending imputation round 8/10, elapsed time 118.58
# [IterativeImputer] Ending imputation round 9/10, elapsed time 133.50
# [IterativeImputer] Ending imputation round 10/10, elapsed time 148.28
# Imputation round 4
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 14.57
# [IterativeImputer] Ending imputation round 2/10, elapsed time 29.07
# [IterativeImputer] Ending imputation round 3/10, elapsed time 43.60
# [IterativeImputer] Ending imputation round 4/10, elapsed time 58.19
# [IterativeImputer] Ending imputation round 5/10, elapsed time 72.68
# [IterativeImputer] Ending imputation round 6/10, elapsed time 87.37
# [IterativeImputer] Ending imputation round 7/10, elapsed time 102.24
# [IterativeImputer] Ending imputation round 8/10, elapsed time 116.89
# [IterativeImputer] Ending imputation round 9/10, elapsed time 131.63
# [IterativeImputer] Ending imputation round 10/10, elapsed time 146.15
# Imputation round 5
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 15834.50
# [IterativeImputer] Ending imputation round 2/10, elapsed time 15849.68
# [IterativeImputer] Ending imputation round 3/10, elapsed time 15865.57
# [IterativeImputer] Ending imputation round 4/10, elapsed time 15881.59
# [IterativeImputer] Ending imputation round 5/10, elapsed time 15910.75
# [IterativeImputer] Ending imputation round 6/10, elapsed time 15948.41
# [IterativeImputer] Ending imputation round 7/10, elapsed time 15984.18
# [IterativeImputer] Ending imputation round 8/10, elapsed time 16018.87
# [IterativeImputer] Ending imputation round 9/10, elapsed time 16054.83
# [IterativeImputer] Ending imputation round 10/10, elapsed time 16089.32
# Imputation round 6
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 30.74
# [IterativeImputer] Ending imputation round 2/10, elapsed time 68.11
# [IterativeImputer] Ending imputation round 3/10, elapsed time 102.77
# [IterativeImputer] Ending imputation round 4/10, elapsed time 137.21
# [IterativeImputer] Ending imputation round 5/10, elapsed time 166.38
# [IterativeImputer] Ending imputation round 6/10, elapsed time 212.09
# [IterativeImputer] Ending imputation round 7/10, elapsed time 251.57
# [IterativeImputer] Ending imputation round 8/10, elapsed time 303.33
# [IterativeImputer] Ending imputation round 9/10, elapsed time 353.95
# [IterativeImputer] Ending imputation round 10/10, elapsed time 403.58
# Imputation round 7
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 50.79
# [IterativeImputer] Ending imputation round 2/10, elapsed time 84.06
# [IterativeImputer] Ending imputation round 3/10, elapsed time 115.74
# [IterativeImputer] Ending imputation round 4/10, elapsed time 162.74
# [IterativeImputer] Ending imputation round 5/10, elapsed time 201.43
# [IterativeImputer] Ending imputation round 6/10, elapsed time 242.27
# [IterativeImputer] Ending imputation round 7/10, elapsed time 266.25
# [IterativeImputer] Ending imputation round 8/10, elapsed time 290.01
# [IterativeImputer] Ending imputation round 9/10, elapsed time 312.83
# [IterativeImputer] Ending imputation round 10/10, elapsed time 335.56
# Imputation round 8
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 22.39
# [IterativeImputer] Ending imputation round 2/10, elapsed time 45.08
# [IterativeImputer] Ending imputation round 3/10, elapsed time 68.94
# [IterativeImputer] Ending imputation round 4/10, elapsed time 91.27
# [IterativeImputer] Ending imputation round 5/10, elapsed time 115.72
# [IterativeImputer] Ending imputation round 6/10, elapsed time 139.64
# [IterativeImputer] Ending imputation round 7/10, elapsed time 163.31
# [IterativeImputer] Ending imputation round 8/10, elapsed time 201.06
# [IterativeImputer] Ending imputation round 9/10, elapsed time 227.19
# [IterativeImputer] Ending imputation round 10/10, elapsed time 251.32
# Imputation round 9
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 31.37
# [IterativeImputer] Ending imputation round 2/10, elapsed time 58.82
# [IterativeImputer] Ending imputation round 3/10, elapsed time 101.77
# [IterativeImputer] Ending imputation round 4/10, elapsed time 131.24
# [IterativeImputer] Ending imputation round 5/10, elapsed time 170.80
# [IterativeImputer] Ending imputation round 6/10, elapsed time 192.86
# [IterativeImputer] Ending imputation round 7/10, elapsed time 216.14
# [IterativeImputer] Ending imputation round 8/10, elapsed time 238.82
# [IterativeImputer] Ending imputation round 9/10, elapsed time 265.08
# [IterativeImputer] Ending imputation round 10/10, elapsed time 294.32
# Imputation round 10
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 33.85
# [IterativeImputer] Ending imputation round 2/10, elapsed time 69.86
# [IterativeImputer] Ending imputation round 3/10, elapsed time 102.22
# [IterativeImputer] Ending imputation round 4/10, elapsed time 135.19
# [IterativeImputer] Ending imputation round 5/10, elapsed time 175.19
# [IterativeImputer] Ending imputation round 6/10, elapsed time 213.17
# [IterativeImputer] Ending imputation round 7/10, elapsed time 256.71
# [IterativeImputer] Ending imputation round 8/10, elapsed time 298.72
# [IterativeImputer] Ending imputation round 9/10, elapsed time 334.48
# [IterativeImputer] Ending imputation round 10/10, elapsed time 365.60
# Imputation round 11
# [IterativeImputer] Completing matrix with shape (26070, 31)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 25.49
# [IterativeImputer] Ending imputation round 2/10, elapsed time 54.26

# %%
r2

# %%
r3, r3_detail = run_all(0.1)

# %%
r3
